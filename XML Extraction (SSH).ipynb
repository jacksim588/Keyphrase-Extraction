# %%
import os
import pandas as pd
from tqdm import tqdm
from Scripts.XML_Extraction.Extract_XML import extract_from_xml

# %%
import paramiko

# Server details
hostname = 'ec2-18-168-204-252.eu-west-2.compute.amazonaws.com'
username = 'deploy'
pem_file_path = r'G:\$00-Work\ImpactScore\Connecting to EC2\impactscore.pem'
remote_dir = '/mnt/brandbank/7622210249661'

# Connect to the server
try:
    ssh = paramiko.SSHClient()
    ssh.set_missing_host_key_policy(paramiko.AutoAddPolicy())
    ssh.connect(hostname, username=username, key_filename=pem_file_path)
    
    # Open SFTP session
    sftp = ssh.open_sftp()
    
    # List contents of the specific directory
    items = sftp.listdir(remote_dir)
    
    # Print each item in the directory
    print(f"Contents of '{remote_dir}':")
    for item in items:
        print(item)
    
    # Close the SFTP session and SSH connection
    sftp.close()
    ssh.close()
except Exception as e:
    print("Connection failed:", e)
# Out:
# Contents of '/mnt/brandbank/7622210249661':
# 11420646.xml
# 2413957.xml
# 12173865.jpg
# 11306394.xml
# 5866702.xml
# 5866702.jpg
# 2413957.jpg
# 10618390.xml
# 11306394.jpg
# 12173865.xml
# 11420646.jpg

# %%
import paramiko
from tqdm import tqdm
import pandas as pd
import io
from concurrent.futures import ThreadPoolExecutor, as_completed
import os

# Server details
hostname = 'ec2-18-168-204-252.eu-west-2.compute.amazonaws.com'
username = 'deploy'
remote_dir = '/mnt/brandbank/'
pem_file_path = r'G:\$00-Work\ImpactScore\Connecting to EC2\impactscore.pem'

# Define columns for the final DataFrame
columns = [
    'name', 'gtin', 'isDelete', 'date', 'pl1', 'pl2', 'pl3', 
    'description', 'allergyAdvice', 'recycling', 'recycling_other', 
    'brands', 'marketing', 'ingredients', 'features', 'storage', 'preserves'
]

# Function to process each XML file using a separate SSH connection
def process_file(filename, filepath):
    try:
        print(f"Establishing SSH connection for file {filename}...")

        # Set up a new SSH and SFTP connection for each thread
        ssh = paramiko.SSHClient()
        ssh.set_missing_host_key_policy(paramiko.AutoAddPolicy())
        ssh.connect(hostname, username=username, key_filename=pem_file_path)
        sftp = ssh.open_sftp()

        # Read and process the XML file
        print(f"Processing file: {filename}")
        with sftp.file(filepath, 'r') as file:
            xml_content = file.read().decode('utf-8')
            productList = extract_from_xml(io.StringIO(xml_content), filename)

        # Notify closing of the connection
        print(f"Closing connection for file {filename}...")
        sftp.close()
        ssh.close()
        return productList
    except Exception as e:
        print(f"Failed to process {filename}: {e}")
        return None

# Helper function to recursively find all XML files in subdirectories
def find_all_xml_files(sftp, path):
    xml_files = []
    folders = [path]

    # Initialize tqdm progress bar
    folder_count = 0
    with tqdm(total=len(folders), desc="Processing Folders") as folder_bar:
        # Walk through the directory recursively
        while folders:
            current_folder = folders.pop(0)
            folder_count += 1

            # Update progress bar total dynamically
            folder_bar.total = folder_count
            folder_bar.refresh()
            
            # Process each folder and list its items
            for item in sftp.listdir_attr(current_folder):
                item_path = os.path.join(current_folder, item.filename)
                if item.st_mode & 0o40000:  # Check if it's a directory
                    folders.append(item_path)
                    folder_count += 1
                elif item.filename.endswith('.xml'):  # Check for XML files
                    xml_files.append(item_path)

            folder_bar.update(1)

    print(f"Total folders processed: {folder_count}")
    print(f"Total XML files found: {len(xml_files)}")
    return xml_files

# Main execution with parallel processing
try:
    print("Establishing initial connection to list files...")
    ssh = paramiko.SSHClient()
    ssh.set_missing_host_key_policy(paramiko.AutoAddPolicy())
    ssh.connect(hostname, username=username, key_filename=pem_file_path)
    sftp = ssh.open_sftp()
    
    print("Searching for XML files in all subdirectories...")
    files = find_all_xml_files(sftp, remote_dir)
    sftp.close()
    ssh.close()
    
    if not files:
        print("No XML files found in the directory or its subdirectories.")
    else:
        print("Initial connection closed after finding files.")

        # Process files in parallel using multiple connections
        outList = []
        print("Starting parallel processing of files...")
        with ThreadPoolExecutor(max_workers=4) as executor:
            future_to_file = {executor.submit(process_file, os.path.basename(file), file): file for file in files}

            # Track progress with tqdm and notify each file completion
            with tqdm(total=len(files), desc="Processing XML Files") as pbar:
                for future in as_completed(future_to_file):
                    result = future.result()
                    filename = future_to_file[future]
                    if result:
                        outList.append(result)
                        print(f"File {filename} processed successfully.")
                    else:
                        print(f"File {filename} processing failed.")
                    pbar.update(1)

        # Convert results to DataFrame
        print("Creating final DataFrame...")
        out_df = pd.DataFrame(outList, columns=columns)
        print("DataFrame created successfully with", len(out_df), "records.")

except Exception as e:
    print("Error during processing:", e)

finally:
    print("Closing any remaining open connections.")
# Out:
# Establishing initial connection to list files...
# Searching for XML files in all subdirectories...
# Processing Folders:   1%|          | 3164/505269 [07:25<19:39:36,  7.09it/s]
# Closing any remaining open connections.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 88
#      85 sftp = ssh.open_sftp()
#      87 print("Searching for XML files in all subdirectories...")
# ---> 88 files = find_all_xml_files(sftp, remote_dir)
#      89 sftp.close()
#      90 ssh.close()
#
# Cell In[11], line 65, in find_all_xml_files(sftp, path)
#      62 folder_bar.refresh()
#      64 # Process each folder and list its items
# ---> 65 for item in sftp.listdir_attr(current_folder):
#      66     item_path = os.path.join(current_folder, item.filename)
#      67     if item.st_mode & 0o40000:  # Check if it's a directory
#
# File c:\Users\Jack\AppData\Local\Programs\Python\Python312\Lib\site-packages\paramiko\sftp_client.py:246, in SFTPClient.listdir_attr(self, path)
#     244 while True:
#     245     try:
# --> 246         t, msg = self._request(CMD_READDIR, handle)
#     247     except EOFError:
#     248         # done with handle
#     249         break
#
# File c:\Users\Jack\AppData\Local\Programs\Python\Python312\Lib\site-packages\paramiko\sftp_client.py:857, in SFTPClient._request(self, t, *args)
#     855 def _request(self, t, *args):
#     856     num = self._async_request(type(None), t, *args)
# --> 857     return self._read_response(num)
#
# File c:\Users\Jack\AppData\Local\Programs\Python\Python312\Lib\site-packages\paramiko\sftp_client.py:887, in SFTPClient._read_response(self, waitfor)
#     885 while True:
#     886     try:
# --> 887         t, data = self._read_packet()
#     888     except EOFError as e:
#     889         raise SSHException("Server connection dropped: {}".format(e))
#
# File c:\Users\Jack\AppData\Local\Programs\Python\Python312\Lib\site-packages\paramiko\sftp.py:212, in BaseSFTP._read_packet(self)
#     211 def _read_packet(self):
# --> 212     x = self._read_all(4)
#     213     # most sftp servers won't accept packets larger than about 32k, so
#     214     # anything with the high byte set (> 16MB) is just garbage.
#     215     if byte_ord(x[0]):
#
# File c:\Users\Jack\AppData\Local\Programs\Python\Python312\Lib\site-packages\paramiko\sftp.py:196, in BaseSFTP._read_all(self, n)
#     194             break
#     195 else:
# --> 196     x = self.sock.recv(n)
#     198 if len(x) == 0:
#     199     raise EOFError()
#
# File c:\Users\Jack\AppData\Local\Programs\Python\Python312\Lib\site-packages\paramiko\channel.py:697, in Channel.recv(self, nbytes)
#     684 """
#     685 Receive data from the channel.  The return value is a string
#     686 representing the data received.  The maximum amount of data to be
#    (...)
#     694     if no data is ready before the timeout set by `settimeout`.
#     695 """
#     696 try:
# --> 697     out = self.in_buffer.read(nbytes, self.timeout)
#     698 except PipeTimeout:
#     699     raise socket.timeout()
#
# File c:\Users\Jack\AppData\Local\Programs\Python\Python312\Lib\site-packages\paramiko\buffered_pipe.py:150, in BufferedPipe.read(self, nbytes, timeout)
#     148 while (len(self._buffer) == 0) and not self._closed:
#     149     then = time.time()
# --> 150     self._cv.wait(timeout)
#     151     if timeout is not None:
#     152         timeout -= time.time() - then
#
# File c:\Users\Jack\AppData\Local\Programs\Python\Python312\Lib\threading.py:355, in Condition.wait(self, timeout)
#     353 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     354     if timeout is None:
# --> 355         waiter.acquire()
#     356         gotit = True
#     357     else:
#
# KeyboardInterrupt:

# %%
out_df
# Out:
#                name            gtin  isDelete        date                 pl1  \
# 0        905597.xml   0000000000185         0  2010-08-16       Dairy & Bread
# 1        643362.xml   0000000000246         0  2006-02-24                Deli
# 2        905600.xml   0000000000260         0  2010-08-16       Dairy & Bread
# 3        980223.xml   0000000000581         0  2011-02-28  Fruit & Vegetables
# 4       8445550.xml  00000000006491         0  2020-10-14  Fruit & Vegetables
# ...             ...             ...       ...         ...                 ...
# 157840  2375232.xml   9857423623122         0  2014-08-12         Meat & Fish
# 157841  5596613.xml   9993510358956         0  2018-03-19         Meat & Fish
# 157842  4607178.xml   9999999999994         0  2017-07-20         Meat & Fish
# 157843  6771345.xml   9999999999994         0  2019-03-06         Meat & Fish
# 157844  6921507.xml   9999999999994         0  2020-01-09         Meat & Fish
#
#                         pl2                  pl3  \
# 0       White Bread & Rolls                Other
# 1               Unallocated          Unallocated
# 2       White Bread & Rolls  French Bread/ Rolls
# 3            Salad Products              Peppers
# 4                    Apples         Other Apples
# ...                     ...                  ...
# 157840           Fresh Fish               Salmon
# 157841            Shellfish      Other Shellfish
# 157842                 Lamb           Other Lamb
# 157843       Reformed Meats              Burgers
# 157844     Chicken & Turkey         Other Turkey
#
#                                               description  \
# 0                         Waitrose Fig & Raisin Loaf 400g
# 1                       WR Gingerbread biscuit chick each
# 2                          Waitrose Petit Parisienne 290g
# 3                           Waitrose Loose Yellow Peppers
# 4                                   Asda Pink Lady Apples
# ...                                                   ...
# 157840        Wrights of Howth Sliced Smoked Salmon 400gr
# 157841          Morrisons Fresh Live Scottish Mussels 1kg
# 157842                     Glenmór Lamb Carvery Shoulders
# 157843  Hogan's Farm 12 Buffalo Turkey Burgers and 12 ...
# 157844                  Hogan's 5 Star Half Turkey Breast
#
#                               allergyAdvice recycling recycling_other  \
# 0
# 1
# 2
# 3
# 4
# ...                                     ...       ...             ...
# 157840
# 157841
# 157842
# 157843  Sulphur Dioxide/Sulphites, Contains
# 157844                   Wheat, May Contain
#
#                   brands marketing  \
# 0               Waitrose
# 1
# 2               Waitrose
# 3               Waitrose
# 4                   Asda
# ...                  ...       ...
# 157840  Wrights of Howth
# 157841         Morrisons
# 157842           Glenmór
# 157843      Hogan's Farm
# 157844           Hogan's
#
#                                               ingredients  \
# 0
# 1
# 2
# 3
# 4
# ...                                                   ...
# 157840                Salmon, Salmo Salar Salt, Oak Smoke
# 157841
# 157842
# 157843  Turkey (75%), Buffalo Glaze (Acidity Regulator...
# 157844  Turkey Breast Meat, Salt, Stabilisers (Di, Tri...
#
#                                                  features  \
# 0
# 1
# 2
# 3
# 4
# ...                                                   ...
# 157840
# 157841
# 157842                                Irish country meats
# 157843  High in protein, Low in fat, Fresh class A tur...
# 157844
#
#                                                   storage preserves
# 0
# 1
# 2
# 3
# 4
# ...                                                   ...       ...
# 157840                                  Keep Refrigerated
# 157841  Not Suitable for Home Freezing, Keep Refrigerated
# 157842
# 157843
# 157844                                  Keep Refrigerated
#
# [157845 rows x 17 columns]

# %%
out_df.to_csv(r'Data/Bulk Extract Full_oct_2024.csv', index = False)

# %%
import paramiko
import psycopg2
import io
from tqdm import tqdm
import os
import pandas as pd
from Scripts.XML_Extraction.Extract_XML import extract_from_xml_string

# PostgreSQL connection details
db_config = {
    'database': 'Products_Phrases',
    'user': 'Jack Simpson@impactscoredb',
    'password': 'hycMK>~4~3',  # Replace with actual password
    'host': 'impactscoredb.postgres.database.azure.com',
    'port': '5432'
}

# Server details
hostname = 'ec2-18-168-204-252.eu-west-2.compute.amazonaws.com'
username = 'deploy'
remote_dir = '/mnt/brandbank/'
pem_file_path = r'G:\$00-Work\ImpactScore\Connecting to EC2\impactscore.pem'

# Define columns for the DataFrame
columns = [
    'name', 'gtin', 'isDelete', 'date', 'pl1', 'pl2', 'pl3', 
    'description', 'allergyAdvice', 'recycling', 'recycling_other', 
    'brands', 'marketing', 'ingredients', 'features', 'storage', 'preserves'
]

# Step 1: Retrieve the highest XML ID in the database
def get_highest_xml_id():
    try:
        conn = psycopg2.connect(**db_config)
        cursor = conn.cursor()
        
        # Fetch all XML IDs from the database and get the highest ID
        cursor.execute("SELECT xml_id FROM brandbankxml;")
        max_xml_id = max(int(row[0][:-4]) for row in cursor.fetchall())
        
        cursor.close()
        conn.close()
        print(f"Highest XML ID in the database: {max_xml_id}")
        return max_xml_id
    except Exception as e:
        print(f"Error connecting to PostgreSQL: {e}")
        return 0  # If there are no IDs in the database, start from 0

# Function to process new XML files and return extracted data as a DataFrame
def collect_new_xml_data():
    # Retrieve the highest XML ID from the database
    max_xml_id_in_db = get_highest_xml_id()

    # Establish SSH connection
    ssh = paramiko.SSHClient()
    ssh.set_missing_host_key_policy(paramiko.AutoAddPolicy())
    ssh.connect(hostname, username=username, key_filename=pem_file_path)
    sftp = ssh.open_sftp()
    
    # Initialize an empty list to collect data for DataFrame
    extracted_data_list = []

    # Traverse only first-level directories within the brandbank folder
    print("Traversing first-level directories to find new XML files...")

    with tqdm(desc="Processing Product Folders") as pbar:
        for product_folder in sftp.listdir_attr(remote_dir):
            product_folder_path = f"{remote_dir}/{product_folder.filename}"  # Use '/' as separator
            
            # Ensure we only go one level deep and skip if it's not a directory
            if not (product_folder.st_mode & 0o40000):  # Check if it's a directory
                continue
            
            # Process XML files in the product folder
            for item in sftp.listdir_attr(product_folder_path):
                if item.filename.endswith('.xml'):
                    xml_id = int(item.filename[:-4])  # Convert filename to integer by removing ".xml"
                    item_path = f"{product_folder_path}/{item.filename}"  # Construct path with '/' separator
                    
                    # Process file only if its ID is higher than the max ID in the database
                    if xml_id > max_xml_id_in_db:
                        try:
                            # Read the file content
                            with sftp.open(item_path, 'r') as file:
                                xml_content = file.read().decode('utf-8')
                                
                                # Extract data and append to the list
                                extracted_data = extract_from_xml_string(xml_content, item.filename)
                                extracted_data_list.append(extracted_data)
                                
                        except FileNotFoundError:
                            print(f"File not found: {item_path}")

            pbar.update(1)

    # Close SFTP and SSH connections
    sftp.close()
    ssh.close()

    # Create a DataFrame from the collected data and return it
    out_df = pd.DataFrame(extracted_data_list, columns=columns)
    print("Data collection complete. Returning DataFrame.")
    return out_df

# Run the function to collect data and print the resulting DataFrame
out_df = collect_new_xml_data()
print(out_df)
# Out:
# Highest XML ID in the database: 12698297
# Traversing first-level directories to find new XML files...
# Processing Product Folders: 14203it [43:30,  5.44it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 106
#     103     return out_df
#     105 # Run the function to collect data and print the resulting DataFrame
# --> 106 out_df = collect_new_xml_data()
#     107 print(out_df)
#
# Cell In[1], line 75, in collect_new_xml_data()
#      72     continue
#      74 # Process XML files in the product folder
# ---> 75 for item in sftp.listdir_attr(product_folder_path):
#      76     if item.filename.endswith('.xml'):
#      77         xml_id = int(item.filename[:-4])  # Convert filename to integer by removing ".xml"
#
# File c:\Users\Jack\AppData\Local\Programs\Python\Python312\Lib\site-packages\paramiko\sftp_client.py:246, in SFTPClient.listdir_attr(self, path)
#     244 while True:
#     245     try:
# --> 246         t, msg = self._request(CMD_READDIR, handle)
#     247     except EOFError:
#     248         # done with handle
#     249         break
#
# File c:\Users\Jack\AppData\Local\Programs\Python\Python312\Lib\site-packages\paramiko\sftp_client.py:857, in SFTPClient._request(self, t, *args)
#     855 def _request(self, t, *args):
#     856     num = self._async_request(type(None), t, *args)
# --> 857     return self._read_response(num)
#
# File c:\Users\Jack\AppData\Local\Programs\Python\Python312\Lib\site-packages\paramiko\sftp_client.py:887, in SFTPClient._read_response(self, waitfor)
#     885 while True:
#     886     try:
# --> 887         t, data = self._read_packet()
#     888     except EOFError as e:
#     889         raise SSHException("Server connection dropped: {}".format(e))
#
# File c:\Users\Jack\AppData\Local\Programs\Python\Python312\Lib\site-packages\paramiko\sftp.py:212, in BaseSFTP._read_packet(self)
#     211 def _read_packet(self):
# --> 212     x = self._read_all(4)
#     213     # most sftp servers won't accept packets larger than about 32k, so
#     214     # anything with the high byte set (> 16MB) is just garbage.
#     215     if byte_ord(x[0]):
#
# File c:\Users\Jack\AppData\Local\Programs\Python\Python312\Lib\site-packages\paramiko\sftp.py:196, in BaseSFTP._read_all(self, n)
#     194             break
#     195 else:
# --> 196     x = self.sock.recv(n)
#     198 if len(x) == 0:
#     199     raise EOFError()
#
# File c:\Users\Jack\AppData\Local\Programs\Python\Python312\Lib\site-packages\paramiko\channel.py:697, in Channel.recv(self, nbytes)
#     684 """
#     685 Receive data from the channel.  The return value is a string
#     686 representing the data received.  The maximum amount of data to be
#    (...)
#     694     if no data is ready before the timeout set by `settimeout`.
#     695 """
#     696 try:
# --> 697     out = self.in_buffer.read(nbytes, self.timeout)
#     698 except PipeTimeout:
#     699     raise socket.timeout()
#
# File c:\Users\Jack\AppData\Local\Programs\Python\Python312\Lib\site-packages\paramiko\buffered_pipe.py:150, in BufferedPipe.read(self, nbytes, timeout)
#     148 while (len(self._buffer) == 0) and not self._closed:
#     149     then = time.time()
# --> 150     self._cv.wait(timeout)
#     151     if timeout is not None:
#     152         timeout -= time.time() - then
#
# File c:\Users\Jack\AppData\Local\Programs\Python\Python312\Lib\threading.py:355, in Condition.wait(self, timeout)
#     353 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     354     if timeout is None:
# --> 355         waiter.acquire()
#     356         gotit = True
#     357     else:
#
# KeyboardInterrupt:

# %%
def get_highest_xml_id():
    try:
        conn = psycopg2.connect(**db_config)
        cursor = conn.cursor()
        
        # Fetch all XML IDs from the database and get the highest ID
        cursor.execute("SELECT xml_id FROM brandbankxml;")
        max_xml_id = max(int(row[0][:-4]) for row in cursor.fetchall())
        
        cursor.close()
        conn.close()
        print(f"Highest XML ID in the database: {max_xml_id}")
        return max_xml_id
    except Exception as e:
        print(f"Error connecting to PostgreSQL: {e}")
        return 0  # If there are no IDs in the database, start from 0

# %% [markdown]
# compare against all xml_ids

# %%
import paramiko
import psycopg2
import io
import os
from tqdm import tqdm
import pandas as pd
from concurrent.futures import ThreadPoolExecutor, as_completed
from Scripts.XML_Extraction.Extract_XML import extract_from_xml_string  # Assuming this is your function

# PostgreSQL connection details
db_config = {
    'database': 'Products_Phrases',
    'user': 'Jack Simpson@impactscoredb',
    'password': 'hycMK>~4~3',  # Replace with actual password
    'host': 'impactscoredb.postgres.database.azure.com',
    'port': '5432'
}

# Server details
hostname = 'ec2-18-168-204-252.eu-west-2.compute.amazonaws.com'
username = 'deploy'
remote_dir = '/mnt/brandbank/'
pem_file_path = r'G:\$00-Work\ImpactScore\Connecting to EC2\impactscore.pem'

# Define columns for the DataFrame
columns = [
    'name', 'gtin', 'isDelete', 'date', 'pl1', 'pl2', 'pl3', 
    'description', 'allergyAdvice', 'recycling', 'recycling_other', 
    'brands', 'marketing', 'ingredients', 'features', 'storage', 'preserves'
]

# Step 1: Retrieve all XML IDs in the database and store them in a set
def get_all_xml_ids():
    try:
        conn = psycopg2.connect(**db_config)
        cursor = conn.cursor()
        
        # Fetch all XML IDs from the database
        cursor.execute("SELECT xml_id FROM brandbankxml;")
        xml_ids = cursor.fetchall()
        
        # Convert to a set for fast lookup
        xml_ids_set = {xml_id[0] for xml_id in xml_ids}
        
        cursor.close()
        conn.close()
        print(f"Total XML IDs retrieved from the database: {len(xml_ids_set)}")
        return xml_ids_set
    except Exception as e:
        print(f"Error connecting to PostgreSQL: {e}")
        return set()

# Function to process each XML file using a separate SSH connection
def process_file(filename, filepath):
    try:
        ssh = paramiko.SSHClient()
        ssh.set_missing_host_key_policy(paramiko.AutoAddPolicy())
        ssh.connect(hostname, username=username, key_filename=pem_file_path)
        sftp = ssh.open_sftp()

        with sftp.file(filepath, 'r') as file:
            xml_content = file.read().decode('utf-8')
            product_data = extract_from_xml_string(xml_content, filename)

        sftp.close()
        ssh.close()
        return product_data
    except Exception as e:
        print(f"Failed to process {filename}: {e}")
        return None

# Step 2: Collect a list of XML files to process
def find_all_xml_files(sftp, path, existing_xml_ids):
    xml_files = []
    folders = [path]

    with tqdm(total=len(folders), desc="Processing Folders") as folder_bar:
        while folders:
            current_folder = folders.pop(0)
            try:
                for item in sftp.listdir_attr(current_folder):
                    item_path = f"{current_folder}/{item.filename}"
                    if item.st_mode & 0o40000:
                        folders.append(item_path)
                    elif item.filename.endswith('.xml'):
                        if item.filename not in existing_xml_ids:  # Check if the XML ID is not in the set
                            xml_files.append(item_path)
            except PermissionError:
                print(f"Permission denied for folder: {current_folder}. Skipping...")
            except Exception as e:
                print(f"Error accessing {current_folder}: {e}")
            folder_bar.update(1)

    return xml_files

# Main function to collect and process new XML files
def collect_new_xml_data():
    existing_xml_ids = get_all_xml_ids()

    # Initial SSH connection to gather XML file paths
    ssh = paramiko.SSHClient()
    ssh.set_missing_host_key_policy(paramiko.AutoAddPolicy())
    ssh.connect(hostname, username=username, key_filename=pem_file_path)
    sftp = ssh.open_sftp()

    print("Searching for XML files in all subdirectories...")
    files_to_process = find_all_xml_files(sftp, remote_dir, existing_xml_ids)
    sftp.close()
    ssh.close()

    # Process files in parallel using multiple connections
    extracted_data_list = []
    print("Starting parallel processing of files...")
    with ThreadPoolExecutor(max_workers=8) as executor:
        future_to_file = {executor.submit(process_file, os.path.basename(file), file): file for file in files_to_process}

        with tqdm(total=len(files_to_process), desc="Processing XML Files") as pbar:
            for future in as_completed(future_to_file):
                result = future.result()
                if result:
                    extracted_data_list.append(result)
                pbar.update(1)
    
    # Create DataFrame from collected data
    out_df = pd.DataFrame(extracted_data_list)
    print("Data collection complete. Returning DataFrame.")
    return out_df

# Run the function to collect data and print the resulting DataFrame
out_df2 = collect_new_xml_data()
out_df2.to_csv('data/new_xml2.csv', index=False)
print(out_df2)
# Out:
# Total XML IDs retrieved from the database: 894837
# Searching for XML files in all subdirectories...
# Processing Folders: 313280it [8:10:24, 12.32it/s]
# Permission denied for folder: /mnt/brandbank//lost+found. Skipping...
# Processing Folders: 478949it [12:24:06,  7.12it/s]Socket exception: An existing connection was forcibly closed by the remote host (10054)
# Processing Folders: 483797it [12:24:27, 380.29it/s]
# Error accessing /mnt/brandbank//5060510763425: Server connection dropped:
# Error accessing /mnt/brandbank//3307210254122: Socket is closed
# Error accessing /mnt/brandbank//5000225055002: Socket is closed
# Error accessing /mnt/brandbank//0000001291810: Socket is closed
# Error accessing /mnt/brandbank//5051413597347: Socket is closed
# Error accessing /mnt/brandbank//5000328139173: Socket is closed
# Error accessing /mnt/brandbank//8005110630415: Socket is closed
# Error accessing /mnt/brandbank//5056236010356: Socket is closed
# Error accessing /mnt/brandbank//0000000439169: Socket is closed
# Error accessing /mnt/brandbank//5050854518386: Socket is closed
# Error accessing /mnt/brandbank//0256770000003: Socket is closed
# Error accessing /mnt/brandbank//5063249930984: Socket is closed
# Error accessing /mnt/brandbank//0000000508216: Socket is closed
# Error accessing /mnt/brandbank//5052715097252: Socket is closed
# Error accessing /mnt/brandbank//5000169032992: Socket is closed
# Error accessing /mnt/brandbank//8710873999920: Socket is closed
# Error accessing /mnt/brandbank//3052503605524: Socket is closed
# Error accessing /mnt/brandbank//0222710000006: Socket is closed
# Error accessing /mnt/brandbank//8436024720334: Socket is closed
# Error accessing /mnt/brandbank//5029912014153: Socket is closed
# Error accessing /mnt/brandbank//0000001576238: Socket is closed
# Error accessing /mnt/brandbank//9781472158727: Socket is closed
# Error accessing /mnt/brandbank//5039036037075: Socket is closed
# Error accessing /mnt/brandbank//5010357112009: Socket is closed
# Error accessing /mnt/brandbank//5057172134915: Socket is closed
# Error accessing /mnt/brandbank//5035766641179: Socket is closed
# Error accessing /mnt/brandbank//8004260014090: Socket is closed
# Error accessing /mnt/brandbank//5016084000404: Socket is closed
# Error accessing /mnt/brandbank//5012368012064: Socket is closed
# Error accessing /mnt/brandbank//5011581003262: Socket is closed
# Error accessing /mnt/brandbank//5063250248900: Socket is closed
# Error accessing /mnt/brandbank//5099872018485: Socket is closed
# Error accessing /mnt/brandbank//0000000378376: Socket is closed
# Error accessing /mnt/brandbank//5013965601279: Socket is closed
# Error accessing /mnt/brandbank//5060060212350: Socket is closed
# Error accessing /mnt/brandbank//0000000396929: Socket is closed
# Error accessing /mnt/brandbank//5050582564334: Socket is closed
# Error accessing /mnt/brandbank//5012144896505: Socket is closed
# Error accessing /mnt/brandbank//5000431027282: Socket is closed
# Error accessing /mnt/brandbank//5000169233481: Socket is closed
# Error accessing /mnt/brandbank//5060595630223: Socket is closed
# Error accessing /mnt/brandbank//5000169612965: Socket is closed
# Error accessing /mnt/brandbank//5060412212892: Socket is closed
# Error accessing /mnt/brandbank//50749003: Socket is closed
# Error accessing /mnt/brandbank//5900649076556: Socket is closed
# Error accessing /mnt/brandbank//5054781302131: Socket is closed
# Error accessing /mnt/brandbank//5017375071011: Socket is closed
# Error accessing /mnt/brandbank//5000169407646: Socket is closed
# Error accessing /mnt/brandbank//05057172445608: Socket is closed
# Error accessing /mnt/brandbank//0283600002005: Socket is closed
# Error accessing /mnt/brandbank//59085454: Socket is closed
# Error accessing /mnt/brandbank//5023538103239: Socket is closed
# Error accessing /mnt/brandbank//0000000314244: Socket is closed
# Error accessing /mnt/brandbank//5012788053548: Socket is closed
# Error accessing /mnt/brandbank//5740900404465: Socket is closed
# Error accessing /mnt/brandbank//5391397100141: Socket is closed
# Error accessing /mnt/brandbank//5054070016619: Socket is closed
# Error accessing /mnt/brandbank//0000001384963: Socket is closed
# Error accessing /mnt/brandbank//0735850999715: Socket is closed
# Error accessing /mnt/brandbank//8712200676108: Socket is closed
# Error accessing /mnt/brandbank//5010017003951: Socket is closed
# Error accessing /mnt/brandbank//5000158062313: Socket is closed
# Error accessing /mnt/brandbank//0286650000007: Socket is closed
# Error accessing /mnt/brandbank//5000169344521: Socket is closed
# Error accessing /mnt/brandbank//5011039174759: Socket is closed
# Error accessing /mnt/brandbank//8001841698236: Socket is closed
# Error accessing /mnt/brandbank//5060408202418: Socket is closed
# Error accessing /mnt/brandbank//5056051806585: Socket is closed
# Error accessing /mnt/brandbank//5059697711534: Socket is closed
# Error accessing /mnt/brandbank//5010511028382: Socket is closed
# Error accessing /mnt/brandbank//5050854222993: Socket is closed
# Error accessing /mnt/brandbank//5000128968041: Socket is closed
# Error accessing /mnt/brandbank//01511451: Socket is closed
# Error accessing /mnt/brandbank//0043168934817: Socket is closed
# Error accessing /mnt/brandbank//5056499912169: Socket is closed
# Error accessing /mnt/brandbank//01031058: Socket is closed
# Error accessing /mnt/brandbank//5412351343036: Socket is closed
# Error accessing /mnt/brandbank//0000027763780: Socket is closed
# Error accessing /mnt/brandbank//3467452009246: Socket is closed
# Error accessing /mnt/brandbank//5051413916667: Socket is closed
# Error accessing /mnt/brandbank//5054805025572: Socket is closed
# Error accessing /mnt/brandbank//5012035912383: Socket is closed
# Error accessing /mnt/brandbank//0079200472146: Socket is closed
# Error accessing /mnt/brandbank//5055201831231: Socket is closed
# Error accessing /mnt/brandbank//5011522100883: Socket is closed
# Error accessing /mnt/brandbank//8710103997122: Socket is closed
# Error accessing /mnt/brandbank//5027040246101: Socket is closed
# Error accessing /mnt/brandbank//5000169181072: Socket is closed
# Error accessing /mnt/brandbank//8002210132597: Socket is closed
# Error accessing /mnt/brandbank//5010236153031: Socket is closed
# Error accessing /mnt/brandbank//5054781779230: Socket is closed
# Error accessing /mnt/brandbank//5052449123616: Socket is closed
# Error accessing /mnt/brandbank//5055936740488: Socket is closed
# Error accessing /mnt/brandbank//5055170577772: Socket is closed
# Error accessing /mnt/brandbank//8717163058015: Socket is closed
# Error accessing /mnt/brandbank//5010251821229: Socket is closed
# Error accessing /mnt/brandbank//5054070018835: Socket is closed
# Error accessing /mnt/brandbank//8714100075821: Socket is closed
# Error accessing /mnt/brandbank//5051413547007: Socket is closed
# Error accessing /mnt/brandbank//5054781219873: Socket is closed
# Error accessing /mnt/brandbank//5055566900429: Socket is closed
# Error accessing /mnt/brandbank//0000030152786: Socket is closed
# Error accessing /mnt/brandbank//5057967340811: Socket is closed
# Error accessing /mnt/brandbank//5034933781991: Socket is closed
# Error accessing /mnt/brandbank//01719994: Socket is closed
# Error accessing /mnt/brandbank//5053083212421: Socket is closed
# Error accessing /mnt/brandbank//7393714516411: Socket is closed
# Error accessing /mnt/brandbank//5057753894191: Socket is closed
# Error accessing /mnt/brandbank//4015400498087: Socket is closed
# Error accessing /mnt/brandbank//4060800172877: Socket is closed
# Error accessing /mnt/brandbank//5010303134062: Socket is closed
# Error accessing /mnt/brandbank//0027084844528: Socket is closed
# Error accessing /mnt/brandbank//9771355668191: Socket is closed
# Error accessing /mnt/brandbank//5060448950638: Socket is closed
# Error accessing /mnt/brandbank//3600523728190: Socket is closed
# Error accessing /mnt/brandbank//9771478078815: Socket is closed
# Error accessing /mnt/brandbank//5010525155319: Socket is closed
# Error accessing /mnt/brandbank//5015802113242: Socket is closed
# Error accessing /mnt/brandbank//5011522133119: Socket is closed
# Error accessing /mnt/brandbank//0270170000005: Socket is closed
# Error accessing /mnt/brandbank//0017854076785: Socket is closed
# Error accessing /mnt/brandbank//5054781461029: Socket is closed
# Error accessing /mnt/brandbank//5707577201179: Socket is closed
# Error accessing /mnt/brandbank//8445290161161: Socket is closed
# Error accessing /mnt/brandbank//5010525158723: Socket is closed
# Error accessing /mnt/brandbank//5010525050973: Socket is closed
# Error accessing /mnt/brandbank//5056176245399: Socket is closed
# Error accessing /mnt/brandbank//6941976231804: Socket is closed
# Error accessing /mnt/brandbank//0082896062621: Socket is closed
# Error accessing /mnt/brandbank//5010594320328: Socket is closed
# Error accessing /mnt/brandbank//5052449643725: Socket is closed
# Error accessing /mnt/brandbank//5057172825349: Socket is closed
# Error accessing /mnt/brandbank//0000030188662: Socket is closed
# Error accessing /mnt/brandbank//5000128914680: Socket is closed
# Error accessing /mnt/brandbank//01035698: Socket is closed
# Error accessing /mnt/brandbank//0043168395694: Socket is closed
# Error accessing /mnt/brandbank//5000128653053: Socket is closed
# Error accessing /mnt/brandbank//5055757100003: Socket is closed
# Error accessing /mnt/brandbank//0000001034981: Socket is closed
# Error accessing /mnt/brandbank//0000000336215: Socket is closed
# Error accessing /mnt/brandbank//5010292924378: Socket is closed
# Error accessing /mnt/brandbank//5010251870494: Socket is closed
# Error accessing /mnt/brandbank//5000159514194: Socket is closed
# Error accessing /mnt/brandbank//5099563104442: Socket is closed
# Error accessing /mnt/brandbank//5060265861728: Socket is closed
# Error accessing /mnt/brandbank//3384128001345: Socket is closed
# Error accessing /mnt/brandbank//8710908881237: Socket is closed
# Error accessing /mnt/brandbank//5000169704349: Socket is closed
# Error accessing /mnt/brandbank//8717163687611: Socket is closed
# Error accessing /mnt/brandbank//5055496708621: Socket is closed
# Error accessing /mnt/brandbank//05000147927074: Socket is closed
# Error accessing /mnt/brandbank//8595606406742: Socket is closed
# Error accessing /mnt/brandbank//5016648910002: Socket is closed
# Error accessing /mnt/brandbank//5000169586389: Socket is closed
# Error accessing /mnt/brandbank//5055158008366: Socket is closed
# Error accessing /mnt/brandbank//0635494363210: Socket is closed
# Error accessing /mnt/brandbank//0017854075665: Socket is closed
# Error accessing /mnt/brandbank//5052449342635: Socket is closed
# Error accessing /mnt/brandbank//5000169321119: Socket is closed
# Error accessing /mnt/brandbank//5010251686781: Socket is closed
# Error accessing /mnt/brandbank//0746775203320: Socket is closed
# Error accessing /mnt/brandbank//5397199001105: Socket is closed
# Error accessing /mnt/brandbank//5057753900335: Socket is closed
# Error accessing /mnt/brandbank//9780008301316: Socket is closed
# Error accessing /mnt/brandbank//5391512926724: Socket is closed
# Error accessing /mnt/brandbank//30141506: Socket is closed
# Error accessing /mnt/brandbank//0000000511803: Socket is closed
# Error accessing /mnt/brandbank//8717418491338: Socket is closed
# Error accessing /mnt/brandbank//5034083000591: Socket is closed
# Error accessing /mnt/brandbank//5059853396742: Socket is closed
# Error accessing /mnt/brandbank//5019998632440: Socket is closed
# Error accessing /mnt/brandbank//5011835101690: Socket is closed
# Error accessing /mnt/brandbank//5000169388464: Socket is closed
# Error accessing /mnt/brandbank//5057172130801: Socket is closed
# Error accessing /mnt/brandbank//5060193613000: Socket is closed
# Error accessing /mnt/brandbank//5060065300830: Socket is closed
# Error accessing /mnt/brandbank//0223230000002: Socket is closed
# Error accessing /mnt/brandbank//5010511473076: Socket is closed
# Error accessing /mnt/brandbank//5010549305028: Socket is closed
# Error accessing /mnt/brandbank//8710908817182: Socket is closed
# Error accessing /mnt/brandbank//5033601765776: Socket is closed
# Error accessing /mnt/brandbank//5010386101234: Socket is closed
# Error accessing /mnt/brandbank//01431230: Socket is closed
# Error accessing /mnt/brandbank//5054781072737: Socket is closed
# Error accessing /mnt/brandbank//5022374024982: Socket is closed
# Error accessing /mnt/brandbank//5063089476550: Socket is closed
# Error accessing /mnt/brandbank//5033904001700: Socket is closed
# Error accessing /mnt/brandbank//5056617572534: Socket is closed
# Error accessing /mnt/brandbank//9780007285235: Socket is closed
# Error accessing /mnt/brandbank//9770966093156: Socket is closed
# Error accessing /mnt/brandbank//5019150000520: Socket is closed
# Error accessing /mnt/brandbank//4820181424916: Socket is closed
# Error accessing /mnt/brandbank//5014503245726: Socket is closed
# Error accessing /mnt/brandbank//8714100525555: Socket is closed
# Error accessing /mnt/brandbank//5052449375992: Socket is closed
# Error accessing /mnt/brandbank//5099839228674: Socket is closed
# Error accessing /mnt/brandbank//5060188693284: Socket is closed
# Error accessing /mnt/brandbank//7613034375520: Socket is closed
# Error accessing /mnt/brandbank//8000500209783: Socket is closed
# Error accessing /mnt/brandbank//5022235003491: Socket is closed
# Error accessing /mnt/brandbank//5059001018823: Socket is closed
# Error accessing /mnt/brandbank//5052449028270: Socket is closed
# Error accessing /mnt/brandbank//4009900525695: Socket is closed
# Error accessing /mnt/brandbank//5060424341634: Socket is closed
# Error accessing /mnt/brandbank//5054655243331: Socket is closed
# Error accessing /mnt/brandbank//5011182003579: Socket is closed
# Error accessing /mnt/brandbank//4260610290604: Socket is closed
# Error accessing /mnt/brandbank//5060333540999: Socket is closed
# Error accessing /mnt/brandbank//0072417137242: Socket is closed
# Error accessing /mnt/brandbank//8714100674956: Socket is closed
# Error accessing /mnt/brandbank//96169650: Socket is closed
# Error accessing /mnt/brandbank//5057172445516: Socket is closed
# Error accessing /mnt/brandbank//0000009017542: Socket is closed
# Error accessing /mnt/brandbank//5030765034694: Socket is closed
# Error accessing /mnt/brandbank//5013635483259: Socket is closed
# Error accessing /mnt/brandbank//5014379005424: Socket is closed
# Error accessing /mnt/brandbank//5099531076733: Socket is closed
# Error accessing /mnt/brandbank//5000169605219: Socket is closed
# Error accessing /mnt/brandbank//5054805038602: Socket is closed
# Error accessing /mnt/brandbank//5060215333763: Socket is closed
# Error accessing /mnt/brandbank//5057618050946: Socket is closed
# Error accessing /mnt/brandbank//5000169326718: Socket is closed
# Error accessing /mnt/brandbank//5060410574381: Socket is closed
# Error accessing /mnt/brandbank//4008177188541: Socket is closed
# Error accessing /mnt/brandbank//9780340978900: Socket is closed
# Error accessing /mnt/brandbank//01625288: Socket is closed
# Error accessing /mnt/brandbank//3800020453506: Socket is closed
# Error accessing /mnt/brandbank//5060201625889: Socket is closed
# Error accessing /mnt/brandbank//03421321: Socket is closed
# Error accessing /mnt/brandbank//5000169091050: Socket is closed
# Error accessing /mnt/brandbank//5098878002245: Socket is closed
# Error accessing /mnt/brandbank//0000000316224: Socket is closed
# Error accessing /mnt/brandbank//5015096995982: Socket is closed
# Error accessing /mnt/brandbank//5054070810583: Socket is closed
# Error accessing /mnt/brandbank//5054781537014: Socket is closed
# Error accessing /mnt/brandbank//5000169551325: Socket is closed
# Error accessing /mnt/brandbank//5010677840057: Socket is closed
# Error accessing /mnt/brandbank//5010251980339: Socket is closed
# Error accessing /mnt/brandbank//5011792001972: Socket is closed
# Error accessing /mnt/brandbank//5057172201648: Socket is closed
# Error accessing /mnt/brandbank//5000169095171: Socket is closed
# Error accessing /mnt/brandbank//5063089125175: Socket is closed
# Error accessing /mnt/brandbank//5054070183342: Socket is closed
# Error accessing /mnt/brandbank//5011262164237: Socket is closed
# Error accessing /mnt/brandbank//7804303001497: Socket is closed
# Error accessing /mnt/brandbank//5035924675411: Socket is closed
# Error accessing /mnt/brandbank//5052449310153: Socket is closed
# Error accessing /mnt/brandbank//0210700000000: Socket is closed
# Error accessing /mnt/brandbank//01733563: Socket is closed
# Error accessing /mnt/brandbank//8710908397325: Socket is closed
# Error accessing /mnt/brandbank//5000169153970: Socket is closed
# Error accessing /mnt/brandbank//3600523527861: Socket is closed
# Error accessing /mnt/brandbank//5063249894217: Socket is closed
# Error accessing /mnt/brandbank//5028235011504: Socket is closed
# Error accessing /mnt/brandbank//3600521796221: Socket is closed
# Error accessing /mnt/brandbank//5051368262437: Socket is closed
# Error accessing /mnt/brandbank//5391520185830: Socket is closed
# Error accessing /mnt/brandbank//5011417556337: Socket is closed
# Error accessing /mnt/brandbank//0888750806123: Socket is closed
# Error accessing /mnt/brandbank//5060038029492: Socket is closed
# Error accessing /mnt/brandbank//5054781374336: Socket is closed
# Error accessing /mnt/brandbank//8720182781925: Socket is closed
# Error accessing /mnt/brandbank//5056567057396: Socket is closed
# Error accessing /mnt/brandbank//3600531632335: Socket is closed
# Error accessing /mnt/brandbank//5025123210148: Socket is closed
# Error accessing /mnt/brandbank//5010353321214: Socket is closed
# Error accessing /mnt/brandbank//5029788190708: Socket is closed
# Error accessing /mnt/brandbank//5010238012749: Socket is closed
# Error accessing /mnt/brandbank//5022977010689: Socket is closed
# Error accessing /mnt/brandbank//3574661591148: Socket is closed
# Error accessing /mnt/brandbank//0291500000007: Socket is closed
# Error accessing /mnt/brandbank//5060219990214: Socket is closed
# Error accessing /mnt/brandbank//5000325053922: Socket is closed
# Error accessing /mnt/brandbank//5391526414422: Socket is closed
# Error accessing /mnt/brandbank//01292176: Socket is closed
# Error accessing /mnt/brandbank//5059697762192: Socket is closed
# Error accessing /mnt/brandbank//5060123602012: Socket is closed
# Error accessing /mnt/brandbank//5000169467800: Socket is closed
# Error accessing /mnt/brandbank//5052514015716: Socket is closed
# Error accessing /mnt/brandbank//5000169287347: Socket is closed
# Error accessing /mnt/brandbank//5012035955892: Socket is closed
# Error accessing /mnt/brandbank//5010251881346: Socket is closed
# Error accessing /mnt/brandbank//8006540163061: Socket is closed
# Error accessing /mnt/brandbank//0000000528016: Socket is closed
# Error accessing /mnt/brandbank//5031390115550: Socket is closed
# Error accessing /mnt/brandbank//5063089414996: Socket is closed
# Error accessing /mnt/brandbank//5051892211918: Socket is closed
# Error accessing /mnt/brandbank//3250670700817: Socket is closed
# Error accessing /mnt/brandbank//5054775859702: Socket is closed
# Error accessing /mnt/brandbank//0718122648191: Socket is closed
# Error accessing /mnt/brandbank//5052197023350: Socket is closed
# Error accessing /mnt/brandbank//5052449598353: Socket is closed
# Error accessing /mnt/brandbank//0838485014157: Socket is closed
# Error accessing /mnt/brandbank//3030053178453: Socket is closed
# Error accessing /mnt/brandbank//5051892211925: Socket is closed
# Error accessing /mnt/brandbank//5060402905384: Socket is closed
# Error accessing /mnt/brandbank//5054014815728: Socket is closed
# Error accessing /mnt/brandbank//5000382106425: Socket is closed
# Error accessing /mnt/brandbank//5060264543908: Socket is closed
# Error accessing /mnt/brandbank//5052449032390: Socket is closed
# Error accessing /mnt/brandbank//5056053308995: Socket is closed
# Error accessing /mnt/brandbank//5000157140449: Socket is closed
# Error accessing /mnt/brandbank//01733532: Socket is closed
# Error accessing /mnt/brandbank//3663555004557: Socket is closed
# Error accessing /mnt/brandbank//5063249371855: Socket is closed
# Error accessing /mnt/brandbank//0644929475947: Socket is closed
# Error accessing /mnt/brandbank//9781407531038: Socket is closed
# Error accessing /mnt/brandbank//5390054042640: Socket is closed
# Error accessing /mnt/brandbank//5060579990053: Socket is closed
# Error accessing /mnt/brandbank//5059944013718: Socket is closed
# Error accessing /mnt/brandbank//5024121133510: Socket is closed
# Error accessing /mnt/brandbank//5054070335406: Socket is closed
# Error accessing /mnt/brandbank//5021320160781: Socket is closed
# Error accessing /mnt/brandbank//5026109009350: Socket is closed
# Error accessing /mnt/brandbank//9414202074522: Socket is closed
# Error accessing /mnt/brandbank//3800020453513: Socket is closed
# Error accessing /mnt/brandbank//5000197582520: Socket is closed
# Error accessing /mnt/brandbank//5054781124788: Socket is closed
# Error accessing /mnt/brandbank//9781910552216: Socket is closed
# Error accessing /mnt/brandbank//01456516: Socket is closed
# Error accessing /mnt/brandbank//5057172338689: Socket is closed
# Error accessing /mnt/brandbank//5000422349980: Socket is closed
# Error accessing /mnt/brandbank//5000169187272: Socket is closed
# Error accessing /mnt/brandbank//5027899300504: Socket is closed
# Error accessing /mnt/brandbank//0000003334317: Socket is closed
# Error accessing /mnt/brandbank//5029266000000: Socket is closed
# Error accessing /mnt/brandbank//5063249571514: Socket is closed
# Error accessing /mnt/brandbank//5059697760402: Socket is closed
# Error accessing /mnt/brandbank//5036854008058: Socket is closed
# Error accessing /mnt/brandbank//5010251986645: Socket is closed
# Error accessing /mnt/brandbank//9780241665961: Socket is closed
# Error accessing /mnt/brandbank//5051562006806: Socket is closed
# Error accessing /mnt/brandbank//3607349607593: Socket is closed
# Error accessing /mnt/brandbank//5051413625118: Socket is closed
# Error accessing /mnt/brandbank//5014555016565: Socket is closed
# Error accessing /mnt/brandbank//0222270000003: Socket is closed
# Error accessing /mnt/brandbank//0043647822062: Socket is closed
# Error accessing /mnt/brandbank//4210201236023: Socket is closed
# Error accessing /mnt/brandbank//5000239103812: Socket is closed
# Error accessing /mnt/brandbank//5050854670299: Socket is closed
# Error accessing /mnt/brandbank//3307219932342: Socket is closed
# Error accessing /mnt/brandbank//5052449724134: Socket is closed
# Error accessing /mnt/brandbank//5099274000200: Socket is closed
# Error accessing /mnt/brandbank//5052910804846: Socket is closed
# Error accessing /mnt/brandbank//5022545124411: Socket is closed
# Error accessing /mnt/brandbank//5057753905712: Socket is closed
# Error accessing /mnt/brandbank//0000000281072: Socket is closed
# Error accessing /mnt/brandbank//5017007600626: Socket is closed
# Error accessing /mnt/brandbank//5031396032295: Socket is closed
# Error accessing /mnt/brandbank//5000169062616: Socket is closed
# Error accessing /mnt/brandbank//5010525091402: Socket is closed
# Error accessing /mnt/brandbank//5039036092357: Socket is closed
# Error accessing /mnt/brandbank//5391518295046: Socket is closed
# Error accessing /mnt/brandbank//5018811000930: Socket is closed
# Error accessing /mnt/brandbank//5052449293432: Socket is closed
# Error accessing /mnt/brandbank//96097342: Socket is closed
# Error accessing /mnt/brandbank//5060149412565: Socket is closed
# Error accessing /mnt/brandbank//8445290018434: Socket is closed
# Error accessing /mnt/brandbank//01817218: Socket is closed
# Error accessing /mnt/brandbank//3337875597395: Socket is closed
# Error accessing /mnt/brandbank//5010525210414: Socket is closed
# Error accessing /mnt/brandbank//3760167977085: Socket is closed
# Error accessing /mnt/brandbank//5449000304322: Socket is closed
# Error accessing /mnt/brandbank//0704039019803: Socket is closed
# Error accessing /mnt/brandbank//5010251830344: Socket is closed
# Error accessing /mnt/brandbank//5099229003324: Socket is closed
# Error accessing /mnt/brandbank//0263090000002: Socket is closed
# Error accessing /mnt/brandbank//0817885000069: Socket is closed
# Error accessing /mnt/brandbank//5099570520068: Socket is closed
# Error accessing /mnt/brandbank//5063089437896: Socket is closed
# Error accessing /mnt/brandbank//00121255: Socket is closed
# Error accessing /mnt/brandbank//5015877450495: Socket is closed
# Error accessing /mnt/brandbank//5011041002781: Socket is closed
# Error accessing /mnt/brandbank//5052449416169: Socket is closed
# Error accessing /mnt/brandbank//5059944896595: Socket is closed
# Error accessing /mnt/brandbank//5057172845996: Socket is closed
# Error accessing /mnt/brandbank//5063065787250: Socket is closed
# Error accessing /mnt/brandbank//5054267014145: Socket is closed
# Error accessing /mnt/brandbank//5000329002278: Socket is closed
# Error accessing /mnt/brandbank//5052449066616: Socket is closed
# Error accessing /mnt/brandbank//4050538502756: Socket is closed
# Error accessing /mnt/brandbank//96091487: Socket is closed
# Error accessing /mnt/brandbank//5063089685730: Socket is closed
# Error accessing /mnt/brandbank//5010134920025: Socket is closed
# Error accessing /mnt/brandbank//0000027348222: Socket is closed
# Error accessing /mnt/brandbank//5060699290996: Socket is closed
# Error accessing /mnt/brandbank//3600530659180: Socket is closed
# Error accessing /mnt/brandbank//5010525225579: Socket is closed
# Error accessing /mnt/brandbank//4015400835332: Socket is closed
# Error accessing /mnt/brandbank//96197431: Socket is closed
# Error accessing /mnt/brandbank//5000169403723: Socket is closed
# Error accessing /mnt/brandbank//5024121487217: Socket is closed
# Error accessing /mnt/brandbank//5391521781611: Socket is closed
# Error accessing /mnt/brandbank//5060342021854: Socket is closed
# Error accessing /mnt/brandbank//01857603: Socket is closed
# Error accessing /mnt/brandbank//5000159533683: Socket is closed
# Error accessing /mnt/brandbank//3614224219246: Socket is closed
# Error accessing /mnt/brandbank//5011417556313: Socket is closed
# Error accessing /mnt/brandbank//5060191557917: Socket is closed
# Error accessing /mnt/brandbank//5010525249674: Socket is closed
# Error accessing /mnt/brandbank//0000619753076: Socket is closed
# Error accessing /mnt/brandbank//5054781524625: Socket is closed
# Error accessing /mnt/brandbank//0000000172783: Socket is closed
# Error accessing /mnt/brandbank//7622210575036: Socket is closed
# Error accessing /mnt/brandbank//5057172126286: Socket is closed
# Error accessing /mnt/brandbank//5052449663167: Socket is closed
# Error accessing /mnt/brandbank//8712561386326: Socket is closed
# Error accessing /mnt/brandbank//5013427004730: Socket is closed
# Error accessing /mnt/brandbank//5000169263600: Socket is closed
# Error accessing /mnt/brandbank//01352917: Socket is closed
# Error accessing /mnt/brandbank//8006540635698: Socket is closed
# Error accessing /mnt/brandbank//5000169492529: Socket is closed
# Error accessing /mnt/brandbank//5059697698675: Socket is closed
# Error accessing /mnt/brandbank//3600530521944: Socket is closed
# Error accessing /mnt/brandbank//5011673168060: Socket is closed
# Error accessing /mnt/brandbank//5000208092772: Socket is closed
# Error accessing /mnt/brandbank//5010438016288: Socket is closed
# Error accessing /mnt/brandbank//5099902945323: Socket is closed
# Error accessing /mnt/brandbank//5014013806004: Socket is closed
# Error accessing /mnt/brandbank//30171282: Socket is closed
# Error accessing /mnt/brandbank//5000128782050: Socket is closed
# Error accessing /mnt/brandbank//10051405: Socket is closed
# Error accessing /mnt/brandbank//8001841659602: Socket is closed
# Error accessing /mnt/brandbank//9780752884424: Socket is closed
# Error accessing /mnt/brandbank//5391515250079: Socket is closed
# Error accessing /mnt/brandbank//0000001545838: Socket is closed
# Error accessing /mnt/brandbank//01638783: Socket is closed
# Error accessing /mnt/brandbank//01836677: Socket is closed
# Error accessing /mnt/brandbank//00369596: Socket is closed
# Error accessing /mnt/brandbank//5020379169493: Socket is closed
# Error accessing /mnt/brandbank//5000205040899: Socket is closed
# Error accessing /mnt/brandbank//5012583206910: Socket is closed
# Error accessing /mnt/brandbank//5000169528792: Socket is closed
# Error accessing /mnt/brandbank//0711719817567: Socket is closed
# Error accessing /mnt/brandbank//5057753747824: Socket is closed
# Error accessing /mnt/brandbank//5054070922521: Socket is closed
# Error accessing /mnt/brandbank//5010251961888: Socket is closed
# Error accessing /mnt/brandbank//3307215748824: Socket is closed
# Error accessing /mnt/brandbank//00167918: Socket is closed
# Error accessing /mnt/brandbank//5011475181373: Socket is closed
# Error accessing /mnt/brandbank//5054781876601: Socket is closed
# Error accessing /mnt/brandbank//5056079901163: Socket is closed
# Error accessing /mnt/brandbank//5060433990632: Socket is closed
# Error accessing /mnt/brandbank//5000128963855: Socket is closed
# Error accessing /mnt/brandbank//5391501223360: Socket is closed
# Error accessing /mnt/brandbank//5021320161887: Socket is closed
# Error accessing /mnt/brandbank//5063249571491: Socket is closed
# Error accessing /mnt/brandbank//5000169128138: Socket is closed
# Error accessing /mnt/brandbank//5057172014064: Socket is closed
# Error accessing /mnt/brandbank//5000169149669: Socket is closed
# Error accessing /mnt/brandbank//08710908136887: Socket is closed
# Error accessing /mnt/brandbank//5055443683599: Socket is closed
# Error accessing /mnt/brandbank//5000169214909: Socket is closed
# Error accessing /mnt/brandbank//5011773037655: Socket is closed
# Error accessing /mnt/brandbank//5000169270134: Socket is closed
# Error accessing /mnt/brandbank//5057172338856: Socket is closed
# Error accessing /mnt/brandbank//5054781868866: Socket is closed
# Error accessing /mnt/brandbank//0731509605235: Socket is closed
# Error accessing /mnt/brandbank//5018357803828: Socket is closed
# Error accessing /mnt/brandbank//8033087275490: Socket is closed
# Error accessing /mnt/brandbank//5000108923107: Socket is closed
# Error accessing /mnt/brandbank//5010251564041: Socket is closed
# Error accessing /mnt/brandbank//5000169570937: Socket is closed
# Error accessing /mnt/brandbank//5060351710589: Socket is closed
# Error accessing /mnt/brandbank//5054061102383: Socket is closed
# Error accessing /mnt/brandbank//5060236490339: Socket is closed
# Error accessing /mnt/brandbank//5060123600384: Socket is closed
# Error accessing /mnt/brandbank//8006540603642: Socket is closed
# Error accessing /mnt/brandbank//5010251619192: Socket is closed
# Error accessing /mnt/brandbank//5098715004777: Socket is closed
# Error accessing /mnt/brandbank//5010525201122: Socket is closed
# Error accessing /mnt/brandbank//5035822854932: Socket is closed
# Error accessing /mnt/brandbank//5018190004093: Socket is closed
# Error accessing /mnt/brandbank//5051413676486: Socket is closed
# Error accessing /mnt/brandbank//5098900002007: Socket is closed
# Error accessing /mnt/brandbank//3296180000016: Socket is closed
# Error accessing /mnt/brandbank//8710908820731: Socket is closed
# Error accessing /mnt/brandbank//7350113020147: Socket is closed
# Error accessing /mnt/brandbank//5034933963526: Socket is closed
# Error accessing /mnt/brandbank//5060047374897: Socket is closed
# Error accessing /mnt/brandbank//5034467001459: Socket is closed
# Error accessing /mnt/brandbank//5051562007803: Socket is closed
# Error accessing /mnt/brandbank//5060166592196: Socket is closed
# Error accessing /mnt/brandbank//0000000221375: Socket is closed
# Error accessing /mnt/brandbank//5035766183808: Socket is closed
# Error accessing /mnt/brandbank//5029396003360: Socket is closed
# Error accessing /mnt/brandbank//3600550848397: Socket is closed
# Error accessing /mnt/brandbank//5011021003937: Socket is closed
# Error accessing /mnt/brandbank//8700216139502: Socket is closed
# Error accessing /mnt/brandbank//5000169278390: Socket is closed
# Error accessing /mnt/brandbank//5054781982760: Socket is closed
# Error accessing /mnt/brandbank//5000221509127: Socket is closed
# Error accessing /mnt/brandbank//5022111033505: Socket is closed
# Error accessing /mnt/brandbank//5052449635645: Socket is closed
# Error accessing /mnt/brandbank//5000328160764: Socket is closed
# Error accessing /mnt/brandbank//5010525014814: Socket is closed
# Error accessing /mnt/brandbank//7107538771181: Socket is closed
# Error accessing /mnt/brandbank//0667820013049: Socket is closed
# Error accessing /mnt/brandbank//5018605724554: Socket is closed
# Error accessing /mnt/brandbank//9335782000018: Socket is closed
# Error accessing /mnt/brandbank//5063249401583: Socket is closed
# Error accessing /mnt/brandbank//5099466161214: Socket is closed
# Error accessing /mnt/brandbank//5056079901712: Socket is closed
# Error accessing /mnt/brandbank//5051413966334: Socket is closed
# Error accessing /mnt/brandbank//8700216347464: Socket is closed
# Error accessing /mnt/brandbank//9780563362494: Socket is closed
# Error accessing /mnt/brandbank//5000143922233: Socket is closed
# Error accessing /mnt/brandbank//5017414874665: Socket is closed
# Error accessing /mnt/brandbank//5410041184303: Socket is closed
# Error accessing /mnt/brandbank//5391532121710: Socket is closed
# Error accessing /mnt/brandbank//5026489475981: Socket is closed
# Error accessing /mnt/brandbank//50409365: Socket is closed
# Error accessing /mnt/brandbank//0073490180408: Socket is closed
# Error accessing /mnt/brandbank//5054070921197: Socket is closed
# Error accessing /mnt/brandbank//5024121362118: Socket is closed
# Error accessing /mnt/brandbank//0000001499186: Socket is closed
# Error accessing /mnt/brandbank//5060725788626: Socket is closed
# Error accessing /mnt/brandbank//5060153360074: Socket is closed
# Error accessing /mnt/brandbank//0078636807928: Socket is closed
# Error accessing /mnt/brandbank//0000000327770: Socket is closed
# Error accessing /mnt/brandbank//5901588016849: Socket is closed
# Error accessing /mnt/brandbank//5010251604280: Socket is closed
# Error accessing /mnt/brandbank//5052898008076: Socket is closed
# Error accessing /mnt/brandbank//5012583212294: Socket is closed
# Error accessing /mnt/brandbank//0000000497664: Socket is closed
# Error accessing /mnt/brandbank//50072002: Socket is closed
# Error accessing /mnt/brandbank//5063250015816: Socket is closed
# Error accessing /mnt/brandbank//5201184866016: Socket is closed
# Error accessing /mnt/brandbank//4009900506601: Socket is closed
# Error accessing /mnt/brandbank//0071662951054: Socket is closed
# Error accessing /mnt/brandbank//5035139205380: Socket is closed
# Error accessing /mnt/brandbank//26013121: Socket is closed
# Error accessing /mnt/brandbank//5012869542015: Socket is closed
# Error accessing /mnt/brandbank//5054070755020: Socket is closed
# Error accessing /mnt/brandbank//5054070236086: Socket is closed
# Error accessing /mnt/brandbank//5701943100264: Socket is closed
# Error accessing /mnt/brandbank//5052449729382: Socket is closed
# Error accessing /mnt/brandbank//5010525055794: Socket is closed
# Error accessing /mnt/brandbank//5052449394610: Socket is closed
# Error accessing /mnt/brandbank//7322541453668: Socket is closed
# Error accessing /mnt/brandbank//8008698011294: Socket is closed
# Error accessing /mnt/brandbank//5010679019413: Socket is closed
# Error accessing /mnt/brandbank//5702016916812: Socket is closed
# Error accessing /mnt/brandbank//5000128719032: Socket is closed
# Error accessing /mnt/brandbank//5060422099735: Socket is closed
# Error accessing /mnt/brandbank//5010251862246: Socket is closed
# Error accessing /mnt/brandbank//2324520000000: Socket is closed
# Error accessing /mnt/brandbank//5000169278710: Socket is closed
# Error accessing /mnt/brandbank//5029730000826: Socket is closed
# Error accessing /mnt/brandbank//01869521: Socket is closed
# Error accessing /mnt/brandbank//5054070580363: Socket is closed
# Error accessing /mnt/brandbank//5060317355557: Socket is closed
# Error accessing /mnt/brandbank//5000444030736: Socket is closed
# Error accessing /mnt/brandbank//5021290063075: Socket is closed
# Error accessing /mnt/brandbank//0000000222952: Socket is closed
# Error accessing /mnt/brandbank//5060228452475: Socket is closed
# Error accessing /mnt/brandbank//8008698031032: Socket is closed
# Error accessing /mnt/brandbank//0000001875775: Socket is closed
# Error accessing /mnt/brandbank//5060674870007: Socket is closed
# Error accessing /mnt/brandbank//5000119693976: Socket is closed
# Error accessing /mnt/brandbank//9781529514988: Socket is closed
# Error accessing /mnt/brandbank//0883503195875: Socket is closed
# Error accessing /mnt/brandbank//5000169194256: Socket is closed
# Error accessing /mnt/brandbank//5301000230158: Socket is closed
# Error accessing /mnt/brandbank//5063249930731: Socket is closed
# Error accessing /mnt/brandbank//5017375034719: Socket is closed
# Error accessing /mnt/brandbank//5000328159898: Socket is closed
# Error accessing /mnt/brandbank//5000169654477: Socket is closed
# Error accessing /mnt/brandbank//4870016001423: Socket is closed
# Error accessing /mnt/brandbank//5021139136212: Socket is closed
# Error accessing /mnt/brandbank//0024000001980: Socket is closed
# Error accessing /mnt/brandbank//4037400429724: Socket is closed
# Error accessing /mnt/brandbank//5025820004132: Socket is closed
# Error accessing /mnt/brandbank//5027738020815: Socket is closed
# Error accessing /mnt/brandbank//0074170457896: Socket is closed
# Error accessing /mnt/brandbank//0887254631828: Socket is closed
# Error accessing /mnt/brandbank//4007817050620: Socket is closed
# Error accessing /mnt/brandbank//9780007521845: Socket is closed
# Error accessing /mnt/brandbank//8710522602157: Socket is closed
# Error accessing /mnt/brandbank//3337875568784: Socket is closed
# Error accessing /mnt/brandbank//5000169101605: Socket is closed
# Error accessing /mnt/brandbank//5060204241741: Socket is closed
# Error accessing /mnt/brandbank//01151107: Socket is closed
# Error accessing /mnt/brandbank//5000239104376: Socket is closed
# Error accessing /mnt/brandbank//5057753210595: Socket is closed
# Error accessing /mnt/brandbank//5000169012765: Socket is closed
# Error accessing /mnt/brandbank//7896292310704: Socket is closed
# Error accessing /mnt/brandbank//5000436338840: Socket is closed
# Error accessing /mnt/brandbank//5060148920283: Socket is closed
# Error accessing /mnt/brandbank//3600531648039: Socket is closed
# Error accessing /mnt/brandbank//5084482000005: Socket is closed
# Error accessing /mnt/brandbank//0000000470025: Socket is closed
# Error accessing /mnt/brandbank//5010251958666: Socket is closed
# Error accessing /mnt/brandbank//5010251597131: Socket is closed
# Error accessing /mnt/brandbank//5060430292715: Socket is closed
# Error accessing /mnt/brandbank//5034934641966: Socket is closed
# Error accessing /mnt/brandbank//8720181560231: Socket is closed
# Error accessing /mnt/brandbank//5000204919097: Socket is closed
# Error accessing /mnt/brandbank//5000166157445: Socket is closed
# Error accessing /mnt/brandbank//5054781247302: Socket is closed
# Error accessing /mnt/brandbank//8717163702406: Socket is closed
# Error accessing /mnt/brandbank//5057753493516: Socket is closed
# Error accessing /mnt/brandbank//8053676240715: Socket is closed
# Error accessing /mnt/brandbank//6003770000649: Socket is closed
# Error accessing /mnt/brandbank//5027456004630: Socket is closed
# Error accessing /mnt/brandbank//96037829: Socket is closed
# Error accessing /mnt/brandbank//5014138603151: Socket is closed
# Error accessing /mnt/brandbank//5010251757146: Socket is closed
# Error accessing /mnt/brandbank//5060342470225: Socket is closed
# Error accessing /mnt/brandbank//8001090918994: Socket is closed
# Error accessing /mnt/brandbank//7613031356201: Socket is closed
# Error accessing /mnt/brandbank//5060056360546: Socket is closed
# Error accessing /mnt/brandbank//5039303004731: Socket is closed
# Error accessing /mnt/brandbank//5035766641247: Socket is closed
# Error accessing /mnt/brandbank//5000362104755: Socket is closed
# Error accessing /mnt/brandbank//5000169576267: Socket is closed
# Error accessing /mnt/brandbank//5024448561041: Socket is closed
# Error accessing /mnt/brandbank//3258434110001: Socket is closed
# Error accessing /mnt/brandbank//5018374468567: Socket is closed
# Error accessing /mnt/brandbank//0710069108073: Socket is closed
# Error accessing /mnt/brandbank//01496628: Socket is closed
# Error accessing /mnt/brandbank//5011026701654: Socket is closed
# Error accessing /mnt/brandbank//01538335: Socket is closed
# Error accessing /mnt/brandbank//0600753252611: Socket is closed
# Error accessing /mnt/brandbank//5012128397851: Socket is closed
# Error accessing /mnt/brandbank//5018819902670: Socket is closed
# Error accessing /mnt/brandbank//5000169436073: Socket is closed
# Error accessing /mnt/brandbank//00185462: Socket is closed
# Error accessing /mnt/brandbank//5010251980681: Socket is closed
# Error accessing /mnt/brandbank//5010525187723: Socket is closed
# Error accessing /mnt/brandbank//5060079652642: Socket is closed
# Error accessing /mnt/brandbank//5050582565003: Socket is closed
# Error accessing /mnt/brandbank//7290001052372: Socket is closed
# Error accessing /mnt/brandbank//5021139041417: Socket is closed
# Error accessing /mnt/brandbank//9780718184643: Socket is closed
# Error accessing /mnt/brandbank//08710447402436: Socket is closed
# Error accessing /mnt/brandbank//5000128664226: Socket is closed
# Error accessing /mnt/brandbank//5017375073886: Socket is closed
# Error accessing /mnt/brandbank//5000168104119: Socket is closed
# Error accessing /mnt/brandbank//5060478480402: Socket is closed
# Error accessing /mnt/brandbank//4066398010881: Socket is closed
# Error accessing /mnt/brandbank//5060360420783: Socket is closed
# Error accessing /mnt/brandbank//5039023030508: Socket is closed
# Error accessing /mnt/brandbank//5010251592013: Socket is closed
# Error accessing /mnt/brandbank//5060741612240: Socket is closed
# Error accessing /mnt/brandbank//5060296561017: Socket is closed
# Error accessing /mnt/brandbank//5012159039362: Socket is closed
# Error accessing /mnt/brandbank//5019090519397: Socket is closed
# Error accessing /mnt/brandbank//3600540071729: Socket is closed
# Error accessing /mnt/brandbank//0667820011038: Socket is closed
# Error accessing /mnt/brandbank//5060856010252: Socket is closed
# Error accessing /mnt/brandbank//5010478521223: Socket is closed
# Error accessing /mnt/brandbank//0000001239157: Socket is closed
# Error accessing /mnt/brandbank//0085715675347: Socket is closed
# Error accessing /mnt/brandbank//5034931244238: Socket is closed
# Error accessing /mnt/brandbank//5011309067019: Socket is closed
# Error accessing /mnt/brandbank//5390054038230: Socket is closed
# Error accessing /mnt/brandbank//5059697753411: Socket is closed
# Error accessing /mnt/brandbank//5000169478189: Socket is closed
# Error accessing /mnt/brandbank//4062139011797: Socket is closed
# Error accessing /mnt/brandbank//5000169366806: Socket is closed
# Error accessing /mnt/brandbank//3600523728183: Socket is closed
# Error accessing /mnt/brandbank//5019605005193: Socket is closed
# Error accessing /mnt/brandbank//4064666064574: Socket is closed
# Error accessing /mnt/brandbank//9300605043329: Socket is closed
# Error accessing /mnt/brandbank//5060184452656: Socket is closed
# Error accessing /mnt/brandbank//0000027763469: Socket is closed
# Error accessing /mnt/brandbank//5060503230088: Socket is closed
# Error accessing /mnt/brandbank//0000000297448: Socket is closed
# Error accessing /mnt/brandbank//5029376595885: Socket is closed
# Error accessing /mnt/brandbank//5060402906817: Socket is closed
# Error accessing /mnt/brandbank//5015877611841: Socket is closed
# Error accessing /mnt/brandbank//5059512742224: Socket is closed
# Error accessing /mnt/brandbank//9781471121104: Socket is closed
# Error accessing /mnt/brandbank//0000027855973: Socket is closed
# Error accessing /mnt/brandbank//5060403180179: Socket is closed
# Error accessing /mnt/brandbank//01690293: Socket is closed
# Error accessing /mnt/brandbank//4014400935189: Socket is closed
# Error accessing /mnt/brandbank//5000169161227: Socket is closed
# Error accessing /mnt/brandbank//6948949700411: Socket is closed
# Error accessing /mnt/brandbank//5052714084291: Socket is closed
# Error accessing /mnt/brandbank//9780099492351: Socket is closed
# Error accessing /mnt/brandbank//5059139776015: Socket is closed
# Error accessing /mnt/brandbank//7702018971169: Socket is closed
# Error accessing /mnt/brandbank//5000169640005: Socket is closed
# Error accessing /mnt/brandbank//5032714019332: Socket is closed
# Error accessing /mnt/brandbank//0886976074623: Socket is closed
# Error accessing /mnt/brandbank//5000157078629: Socket is closed
# Error accessing /mnt/brandbank//5027148037885: Socket is closed
# Error accessing /mnt/brandbank//5060147590517: Socket is closed
# Error accessing /mnt/brandbank//5099474401715: Socket is closed
# Error accessing /mnt/brandbank//5018389012496: Socket is closed
# Error accessing /mnt/brandbank//5000128864527: Socket is closed
# Error accessing /mnt/brandbank//5099822703553: Socket is closed
# Error accessing /mnt/brandbank//00304993: Socket is closed
# Error accessing /mnt/brandbank//8001090840264: Socket is closed
# Error accessing /mnt/brandbank//0850278004084: Socket is closed
# Error accessing /mnt/brandbank//5390003008284: Socket is closed
# Error accessing /mnt/brandbank//4000349500090: Socket is closed
# Error accessing /mnt/brandbank//5025232464333: Socket is closed
# Error accessing /mnt/brandbank//5011428000676: Socket is closed
# Error accessing /mnt/brandbank//5941341002276: Socket is closed
# Error accessing /mnt/brandbank//5000169476154: Socket is closed
# Error accessing /mnt/brandbank//5000128735780: Socket is closed
# Error accessing /mnt/brandbank//0707226744540: Socket is closed
# Error accessing /mnt/brandbank//5000169038451: Socket is closed
# Error accessing /mnt/brandbank//5057172148431: Socket is closed
# Error accessing /mnt/brandbank//5000169499443: Socket is closed
# Error accessing /mnt/brandbank//5000169103104: Socket is closed
# Error accessing /mnt/brandbank//5000101197505: Socket is closed
# Error accessing /mnt/brandbank//5060232411499: Socket is closed
# Error accessing /mnt/brandbank//8720182378927: Socket is closed
# Error accessing /mnt/brandbank//5011581046979: Socket is closed
# Error accessing /mnt/brandbank//5034231003283: Socket is closed
# Error accessing /mnt/brandbank//5012869541803: Socket is closed
# Error accessing /mnt/brandbank//0072417140907: Socket is closed
# Error accessing /mnt/brandbank//5054781727576: Socket is closed
# Error accessing /mnt/brandbank//5054267012110: Socket is closed
# Error accessing /mnt/brandbank//4048422176336: Socket is closed
# Error accessing /mnt/brandbank//5010994612948: Socket is closed
# Error accessing /mnt/brandbank//73189480: Socket is closed
# Error accessing /mnt/brandbank//5051892219358: Socket is closed
# Error accessing /mnt/brandbank//5010228090016: Socket is closed
# Error accessing /mnt/brandbank//5010867205369: Socket is closed
# Error accessing /mnt/brandbank//5010525184906: Socket is closed
# Error accessing /mnt/brandbank//5010525263786: Socket is closed
# Error accessing /mnt/brandbank//5391518270210: Socket is closed
# Error accessing /mnt/brandbank//0081229002945: Socket is closed
# Error accessing /mnt/brandbank//5900344600520: Socket is closed
# Error accessing /mnt/brandbank//4210201076902: Socket is closed
# Error accessing /mnt/brandbank//5054781649281: Socket is closed
# Error accessing /mnt/brandbank//5000169477939: Socket is closed
# Error accessing /mnt/brandbank//5010251803201: Socket is closed
# Error accessing /mnt/brandbank//4000349860125: Socket is closed
# Error accessing /mnt/brandbank//5000246727742: Socket is closed
# Error accessing /mnt/brandbank//5060040360156: Socket is closed
# Error accessing /mnt/brandbank//5055940101404: Socket is closed
# Error accessing /mnt/brandbank//5059316576544: Socket is closed
# Error accessing /mnt/brandbank//0700461856450: Socket is closed
# Error accessing /mnt/brandbank//0602537164028: Socket is closed
# Error accessing /mnt/brandbank//5011022062452: Socket is closed
# Error accessing /mnt/brandbank//0064894585180: Socket is closed
# Error accessing /mnt/brandbank//5022153101682: Socket is closed
# Error accessing /mnt/brandbank//0000001878530: Socket is closed
# Error accessing /mnt/brandbank//30137851: Socket is closed
# Error accessing /mnt/brandbank//5054805001149: Socket is closed
# ...
# Error accessing /mnt/brandbank//product-processors/gs1-client: Socket is closed
# Error accessing /mnt/brandbank//tesco/202001241946: Socket is closed
# Error accessing /mnt/brandbank//tesco/202005301619: Socket is closed
# Error accessing /mnt/brandbank//tesco/201906281401: Socket is closed
# Error accessing /mnt/brandbank//tesco/201908161548: Socket is closed
# Error accessing /mnt/brandbank//tesco/201907121555: Socket is closed
# Error accessing /mnt/brandbank//tesco/201907261555: Socket is closed
# Error accessing /mnt/brandbank//tesco/201910181403: Socket is closed
# Error accessing /mnt/brandbank//tesco/201910121400: Socket is closed
# Error accessing /mnt/brandbank//tesco/201905291010: Socket is closed
# Error accessing /mnt/brandbank//tesco/202005221601: Socket is closed
# Error accessing /mnt/brandbank//tesco/201906141558: Socket is closed
# Error accessing /mnt/brandbank//tesco/201910111625: Socket is closed
# Error accessing /mnt/brandbank//tesco/202001181601: Socket is closed
# Error accessing /mnt/brandbank//tesco/202005291703: Socket is closed
# Error accessing /mnt/brandbank//tesco/201912161706: Socket is closed
# Error accessing /mnt/brandbank//tesco/201905181403: Socket is closed
# Error accessing /mnt/brandbank//tesco/202006011023: Socket is closed
# Error accessing /mnt/brandbank//tesco/201909271541: Socket is closed
# Error accessing /mnt/brandbank//tesco/202003191117: Socket is closed
# Error accessing /mnt/brandbank//tesco/201906121042: Socket is closed
# Error accessing /mnt/brandbank//tesco/202005151419: Socket is closed
# Error accessing /mnt/brandbank//tesco/202002221856: Socket is closed
# Error accessing /mnt/brandbank//tesco/202003161105: Socket is closed
# Error accessing /mnt/brandbank//tesco/202004031523: Socket is closed
# Error accessing /mnt/brandbank//tesco/202005281747: Socket is closed
# Error accessing /mnt/brandbank//tesco/202004251616: Socket is closed
# Error accessing /mnt/brandbank//tesco/20190510: Socket is closed
# Error accessing /mnt/brandbank//tesco/201910051359: Socket is closed
# Error accessing /mnt/brandbank//tesco/201906151532: Socket is closed
# Error accessing /mnt/brandbank//tesco/201911161559: Socket is closed
# Error accessing /mnt/brandbank//tesco/201905111527: Socket is closed
# Error accessing /mnt/brandbank//tesco/202003281616: Socket is closed
# Error accessing /mnt/brandbank//tesco/202004111416: Socket is closed
# Error accessing /mnt/brandbank//tesco/201907131345: Socket is closed
# Error accessing /mnt/brandbank//tesco/202003161754: Socket is closed
# Error accessing /mnt/brandbank//tesco/201911231402: Socket is closed
# Error accessing /mnt/brandbank//tesco/202005021405: Socket is closed
# Error accessing /mnt/brandbank//tesco/20190928: Socket is closed
# Error accessing /mnt/brandbank//tesco/202002081846: Socket is closed
# Error accessing /mnt/brandbank//tesco/202002211910: Socket is closed
# Error accessing /mnt/brandbank//tesco/202001111604: Socket is closed
# Error accessing /mnt/brandbank//tesco/201909211547: Socket is closed
# Error accessing /mnt/brandbank//tesco/202003271555: Socket is closed
# Error accessing /mnt/brandbank//tesco/201912211559: Socket is closed
# Error accessing /mnt/brandbank//tesco/202005091412: Socket is closed
# Error accessing /mnt/brandbank//tesco/20190924: Socket is closed
# Error accessing /mnt/brandbank//tesco/202003131621: Socket is closed
# Error accessing /mnt/brandbank//tesco/201912301821: Socket is closed
# Error accessing /mnt/brandbank//tesco/202003231056: Socket is closed
# Error accessing /mnt/brandbank//tesco/201912061427: Socket is closed
# Error accessing /mnt/brandbank//tesco/202001251910: Socket is closed
# Error accessing /mnt/brandbank//tesco/201911221605: Socket is closed
# Error accessing /mnt/brandbank//tesco/20190517: Socket is closed
# Error accessing /mnt/brandbank//tesco/201912271417: Socket is closed
# Error accessing /mnt/brandbank//tesco/201912201619: Socket is closed
# Error accessing /mnt/brandbank//tesco/202009101030: Socket is closed
# Error accessing /mnt/brandbank//tesco/201911091401: Socket is closed
# Error accessing /mnt/brandbank//tesco/201909061545: Socket is closed
# Error accessing /mnt/brandbank//tesco/201907061344: Socket is closed
# Error accessing /mnt/brandbank//tesco/201905251534: Socket is closed
# Error accessing /mnt/brandbank//tesco/202001171424: Socket is closed
# Error accessing /mnt/brandbank//tesco/201911291648: Socket is closed
# Error accessing /mnt/brandbank//tesco/202003071910: Socket is closed
# Error accessing /mnt/brandbank//tesco/201906081539: Socket is closed
# Error accessing /mnt/brandbank//tesco/20190501: Socket is closed
# Error accessing /mnt/brandbank//tesco/201908241540: Socket is closed
# Error accessing /mnt/brandbank//tesco/201908231544: Socket is closed
# Error accessing /mnt/brandbank//tesco/202004181415: Socket is closed
# Error accessing /mnt/brandbank//tesco/201906071602: Socket is closed
# Error accessing /mnt/brandbank//tesco/201905101550: Socket is closed
# Error accessing /mnt/brandbank//tesco/201905141123: Socket is closed
# Error accessing /mnt/brandbank//tesco/201906291426: Socket is closed
# Error accessing /mnt/brandbank//tesco/201911011422: Socket is closed
# Error accessing /mnt/brandbank//tesco/20190531: Socket is closed
# Error accessing /mnt/brandbank//tesco/20190524: Socket is closed
# Error accessing /mnt/brandbank//tesco/201910091516: Socket is closed
# Error accessing /mnt/brandbank//tesco/202005081520: Socket is closed
# Error accessing /mnt/brandbank//tesco/202005161416: Socket is closed
# Error accessing /mnt/brandbank//tesco/202003141612: Socket is closed
# Error accessing /mnt/brandbank//tesco/201908091542: Socket is closed
# Error accessing /mnt/brandbank//tesco/201906011412: Socket is closed
# Error accessing /mnt/brandbank//tesco/202004241449: Socket is closed
# Error accessing /mnt/brandbank//tesco/201912281602: Socket is closed
# Error accessing /mnt/brandbank//tesco/201909141555: Socket is closed
# Error accessing /mnt/brandbank//tesco/201909071546: Socket is closed
# Error accessing /mnt/brandbank//tesco/202009281118: Socket is closed
# Error accessing /mnt/brandbank//tesco/201907201537: Socket is closed
# Error accessing /mnt/brandbank//tesco/201908031530: Socket is closed
# Error accessing /mnt/brandbank//tesco/201906221537: Socket is closed
# Error accessing /mnt/brandbank//tesco/202004171501: Socket is closed
# Error accessing /mnt/brandbank//tesco/202005011507: Socket is closed
# Error accessing /mnt/brandbank//tesco/201910191355: Socket is closed
# Error accessing /mnt/brandbank//tesco/201908021541: Socket is closed
# Error accessing /mnt/brandbank//tesco/201906211411: Socket is closed
# Error accessing /mnt/brandbank//tesco/20190507: Socket is closed
# Error accessing /mnt/brandbank//tesco/202001201652: Socket is closed
# Error accessing /mnt/brandbank//tesco/202004041418: Socket is closed
# Error accessing /mnt/brandbank//tesco/202001041556: Socket is closed
# Error accessing /mnt/brandbank//tesco/201908311541: Socket is closed
# Error accessing /mnt/brandbank//tesco/201912141445: Socket is closed
# Error accessing /mnt/brandbank//tesco/202001280114: Socket is closed
# Error accessing /mnt/brandbank//tesco/201911301406: Socket is closed
# Error accessing /mnt/brandbank//tesco/202001031415: Socket is closed
# Error accessing /mnt/brandbank//tesco/201907271532: Socket is closed
# Error accessing /mnt/brandbank//tesco/201910251441: Socket is closed
# Error accessing /mnt/brandbank//tesco/201912071608: Socket is closed
# Error accessing /mnt/brandbank//tesco/201907191551: Socket is closed
# Error accessing /mnt/brandbank//tesco/202003061941: Socket is closed
# Error accessing /mnt/brandbank//tesco/202005290817: Socket is closed
# Error accessing /mnt/brandbank//tesco/202001031952: Socket is closed
# Error accessing /mnt/brandbank//tesco/201909131721: Socket is closed
# Error accessing /mnt/brandbank//tesco/201908171534: Socket is closed
# Error accessing /mnt/brandbank//tesco/201910041440: Socket is closed
# Error accessing /mnt/brandbank//tesco/202002281913: Socket is closed
# Error accessing /mnt/brandbank//tesco/201905151028: Socket is closed
# Error accessing /mnt/brandbank//tesco/201908301548: Socket is closed
# Error accessing /mnt/brandbank//tesco/202009101543: Socket is closed
# Error accessing /mnt/brandbank//tesco/202002142010: Socket is closed
# Error accessing /mnt/brandbank//tesco/202001101421: Socket is closed
# Error accessing /mnt/brandbank//tesco/201908101536: Socket is closed
# Error accessing /mnt/brandbank//tesco/201912131424: Socket is closed
# Error accessing /mnt/brandbank//tesco/202004101702: Socket is closed
# Error accessing /mnt/brandbank//tesco/202006010913: Socket is closed
# Error accessing /mnt/brandbank//tesco/201912122140: Socket is closed
# Error accessing /mnt/brandbank//tesco/201907051227: Socket is closed
# Error accessing /mnt/brandbank//tesco/201911151625: Socket is closed
# Error accessing /mnt/brandbank//tesco/201912131541: Socket is closed
# Error accessing /mnt/brandbank//tesco/202003201628: Socket is closed
# Error accessing /mnt/brandbank//tesco/202005231418: Socket is closed
# Error accessing /mnt/brandbank//tesco/20190502: Socket is closed
# Error accessing /mnt/brandbank//tesco/20190504: Socket is closed
# Error accessing /mnt/brandbank//tesco/201911021402: Socket is closed
# Error accessing /mnt/brandbank//tesco/202003211559: Socket is closed
# Error accessing /mnt/brandbank//tesco/202002151845: Socket is closed
# Error accessing /mnt/brandbank//tesco/201910021142: Socket is closed
# Error accessing /mnt/brandbank//tesco/202001311938: Socket is closed
# Error accessing /mnt/brandbank//tesco/201909201622: Socket is closed
# Error accessing /mnt/brandbank//tesco/201910261404: Socket is closed
# Error accessing /mnt/brandbank//tesco/20190430: Socket is closed
# Error accessing /mnt/brandbank//tesco/202002291854: Socket is closed
# Error accessing /mnt/brandbank//tesco/202001201124: Socket is closed
# Error accessing /mnt/brandbank//tesco/202002011829: Socket is closed
# Error accessing /mnt/brandbank//tesco/201911081421: Socket is closed
# Error accessing /mnt/brandbank//tesco/202002071957: Socket is closed
# Starting parallel processing of files...
# Processing XML Files:   0%|          | 14/15090 [00:20<4:02:48,  1.03it/s]
# Failed to process 10284404.xml: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
# Failed to process 12684303.xml: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
# Failed to process 9485957.xml: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
# Failed to process 12500701.xml: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
# Processing XML Files:  93%|█████████▎| 14066/15090 [35:42<01:52,  9.14it/s]
# Failed to process 13806292.xml: unclosed token: line 198, column 8
# Processing XML Files: 100%|██████████| 15090/15090 [38:14<00:00,  6.58it/s]
# Data collection complete. Returning DataFrame.
#                  0               1   2           3                   4   \
# 0       4663234.xml   5020379124584   1  2017-08-18
# 1      10635409.xml   5000299618394   1  2022-08-04
# 2      12659917.xml   5702017600208   0  2023-12-08  Household & Garden
# 3      12461053.xml   5060427350343   0  2024-01-08  Skin and Hair Care
# 4      10036086.xml   5020379166355   1  2021-12-22
# ...             ...             ...  ..         ...                 ...
# 15080  10340743.xml  03026981373619   1  2022-05-10
# 15081   8431139.xml   5020379144605   1  2020-10-26
# 15082  10296462.xml   0000000462259   1  2022-03-21
# 15083  10404930.xml   5010525194233   1  2022-05-03
# 15084   5947214.xml   5020379139939   1  2018-05-25
#
#                                 5                    6   \
# 0
# 1
# 2                         For Kids                 Toys
# 3      Soaps, Deodorants & Bathing  Soap & Liquid Soaps
# 4
# ...                            ...                  ...
# 15080
# 15081
# 15082
# 15083
# 15084
#
#                                                       7  8  9   \
# 0
# 1
# 2      LEGO Creator 3in1 Hamster Wheel Animal Toy Set...
# 3                     Kids Stuff Blue Foaming Soap 225ml
# 4
# ...                                                  ... .. ..
# 15080
# 15081
# 15082
# 15083
# 15084
#
#                                      10          11 12  \
# 0
# 1
# 2                                              Lego
# 3      Recycle when empty. Do not crush  Kids Stuff
# 4
# ...                                 ...         ... ..
# 15080
# 15081
# 15082
# 15083
# 15084
#
#                                                       13  \
# 0
# 1
# 2
# 3      Aqua (Water), Butane, Isobutane, Propane, Trie...
# 4
# ...                                                  ...
# 15080
# 15081
# 15082
# 15083
# 15084
#
#                                                       14 15 16    17
# 0
# 1
# 2                                                               None
# 3      Blue Foaming Soap, Fun Fruity Fragrance, Gentl...        None
# 4
# ...                                                  ... .. ..   ...
# 15080
# 15081
# 15082
# 15083
# 15084
#
# [15085 rows x 18 columns]

# %%
out_df = out_df2

# %% [markdown]
# Comapare against highest xml_id

# %%
import paramiko
import psycopg2
import io
import os
from tqdm import tqdm
import pandas as pd
from concurrent.futures import ThreadPoolExecutor, as_completed
from Scripts.XML_Extraction.Extract_XML import extract_from_xml_string  # Assuming this is your function

# PostgreSQL connection details
db_config = {
    'database': 'Products_Phrases',
    'user': 'Jack Simpson@impactscoredb',
    'password': 'hycMK>~4~3',  # Replace with actual password
    'host': 'impactscoredb.postgres.database.azure.com',
    'port': '5432'
}

# Server details
hostname = 'ec2-18-168-204-252.eu-west-2.compute.amazonaws.com'
username = 'deploy'
remote_dir = '/mnt/brandbank/'
pem_file_path = r'G:\$00-Work\ImpactScore\Connecting to EC2\impactscore.pem'

# Define columns for the DataFrame
columns = [
    'name', 'gtin', 'isDelete', 'date', 'pl1', 'pl2', 'pl3', 
    'description', 'allergyAdvice', 'recycling', 'recycling_other', 
    'brands', 'marketing', 'ingredients', 'features', 'storage', 'preserves'
]

# Step 1: Retrieve the highest XML ID in the database
def get_highest_xml_id():
    try:
        conn = psycopg2.connect(**db_config)
        cursor = conn.cursor()
        
        # Fetch the highest XML ID from the database
        cursor.execute("SELECT MAX(CAST(SUBSTRING(xml_id, 1, LENGTH(xml_id) - 4) AS INTEGER)) FROM brandbankxml;")
        max_xml_id = cursor.fetchone()[0] or 0
        
        cursor.close()
        conn.close()
        print(f"Highest XML ID in the database: {max_xml_id}")
        return max_xml_id
    except Exception as e:
        print(f"Error connecting to PostgreSQL: {e}")
        return 0

# Function to process each XML file using a separate SSH connection
def process_file(filename, filepath):
    try:
        ssh = paramiko.SSHClient()
        ssh.set_missing_host_key_policy(paramiko.AutoAddPolicy())
        ssh.connect(hostname, username=username, key_filename=pem_file_path)
        sftp = ssh.open_sftp()

        with sftp.file(filepath, 'r') as file:
            xml_content = file.read().decode('utf-8')
            product_data = extract_from_xml_string(xml_content, filename)

        sftp.close()
        ssh.close()
        return product_data
    except Exception as e:
        print(f"Failed to process {filename}: {e}")
        return None

# Step 2: Collect a list of XML files to process
def find_all_xml_files(sftp, path, max_xml_id):
    xml_files = []
    folders = [path]

    with tqdm(total=len(folders), desc="Processing Folders") as folder_bar:
        while folders:
            current_folder = folders.pop(0)
            try:
                for item in sftp.listdir_attr(current_folder):
                    item_path = f"{current_folder}/{item.filename}"
                    if item.st_mode & 0o40000:
                        folders.append(item_path)
                    elif item.filename.endswith('.xml'):
                        xml_id = int(item.filename[:-4])  # Extract numerical ID from filename
                        if xml_id > max_xml_id:  # Only include files with IDs greater than max_xml_id
                            xml_files.append(item_path)
            except PermissionError:
                print(f"Permission denied for folder: {current_folder}. Skipping...")
            except Exception as e:
                print(f"Error accessing {current_folder}: {e}")
            folder_bar.update(1)

    return xml_files

# Main function to collect and process new XML files
def collect_new_xml_data():
    max_xml_id_in_db = get_highest_xml_id()

    # Initial SSH connection to gather XML file paths
    ssh = paramiko.SSHClient()
    ssh.set_missing_host_key_policy(paramiko.AutoAddPolicy())
    ssh.connect(hostname, username=username, key_filename=pem_file_path)
    sftp = ssh.open_sftp()

    print("Searching for XML files in all subdirectories...")
    files_to_process = find_all_xml_files(sftp, remote_dir, max_xml_id_in_db)
    sftp.close()
    ssh.close()

    # Process files in parallel using multiple connections
    extracted_data_list = []
    print("Starting parallel processing of files...")
    with ThreadPoolExecutor(max_workers=8) as executor:
        future_to_file = {executor.submit(process_file, os.path.basename(file), file): file for file in files_to_process}

        with tqdm(total=len(files_to_process), desc="Processing XML Files") as pbar:
            for future in as_completed(future_to_file):
                result = future.result()
                if result:
                    extracted_data_list.append(result)
                pbar.update(1)
    
    # Create DataFrame from collected data
    out_df = pd.DataFrame(extracted_data_list)
    print("Data collection complete. Returning DataFrame.")
    return out_df

# Run the function to collect data and print the resulting DataFrame
out_df = collect_new_xml_data()
out_df.to_csv('data/new_xml.csv', index=False)
print(out_df)
# Out:
# Highest XML ID in the database: 12698297
# Searching for XML files in all subdirectories...
# Processing Folders: 313281it [7:53:50, 12.32it/s]
# Permission denied for folder: /mnt/brandbank//lost+found. Skipping...
# Processing Folders: 571692it [14:20:45, 11.07it/s]
# Starting parallel processing of files...
# Processing XML Files:  89%|████████▉ | 70969/79472 [2:54:51<15:21,  9.22it/s]
# Failed to process 13806292.xml: unclosed token: line 198, column 8
# Processing XML Files: 100%|██████████| 79472/79472 [3:15:43<00:00,  6.77it/s]
# Data collection complete. Returning DataFrame.
#                  0              1   2           3                   4   \
# 0      13104033.xml  5050854280047   0  2024-08-01       Dairy & Bread
# 1      12764831.xml       00389976   0  2024-01-29  Household & Garden
# 2      13740753.xml  5059697755262   0  2024-09-17  Household & Garden
# 3      13234327.xml  5057753923136   0  2024-07-08             Grocery
# 4      13033043.xml  5050665050136   0  2024-05-20    Ready Made Foods
# ...             ...            ...  ..         ...                 ...
# 79466  12967228.xml  5010459000891   0  2024-04-12              Drinks
# 79467  13028180.xml  5060206743861   0  2024-04-09  Fruit & Vegetables
# 79468  12947527.xml  5011308000208   0  2024-04-08             Grocery
# 79469  13420819.xml  5054781461234   0  2024-07-29             Grocery
# 79470  12832749.xml  5063089158609   0  2024-03-07             Grocery
#
#                             5                          6   \
# 0                 Milk & Cream                Fresh Cream
# 1                       Plants                Cut Flowers
# 2                    Utilities                      Other
# 3          Sauces & Condiments  Other Sauces & Condiments
# 4                        Meals                      Other
# ...                        ...                        ...
# 79466                    Water               Still Waters
# 79467          Core Vegetables                    Carrots
# 79468  Speciality/Ethnic Foods      Indian Cooking Sauces
# 79469      Sauces & Condiments                       Dips
# 79470     Mixes, Jelly & Flour                      Other
#
#                                                       7   \
# 0                          Asda Fresh Double Cream 250ml
# 1                                        Beautiful Smile
# 2      Tesco F&I 400TC CTN Tencel Flexi Fitted Sheet ...
# 3                          Tesco Fruity Brown Sauce 445g
# 4           Mug Shot Max Roast Chicken Flavour Pasta 68g
# ...                                                  ...
# 79466  Highland Spring Strawberry Still Spring Water ...
# 79467                  Gilfresh Family Grown Carrots 1kg
# 79468                       Patak's Hot Lime Pickle 283g
# 79469                       Asda Sour Cream & Chive 290g
# 79470                BAKE by ASDA Blue Sprinkles Mix 70g
#
#                                                       8   \
# 0                                         Milk, Contains
# 1
# 2
# 3
# 4      Barley, Contains, Cereals Containing Gluten, M...
# ...                                                  ...
# 79466
# 79467
# 79468  Mustard, Contains, Nuts, May Contain, Peanuts,...
# 79469                     Eggs, Contains, Milk, Contains
# 79470  Milk, Contains, Nuts, May Contain, Peanuts, Ma...
#
#                                                       9   \
# 0                                   Film, Do Not Recycle
# 1
# 2
# 3                                Bottle, Widely Recycled
# 4      Lid, Do Not Recycle, Pot, Recycle, Sleeve, Rec...
# ...                                                  ...
# 79466
# 79467  Film, Plastic - Widely Recycled, Pack, Recycle...
# 79468
# 79469
# 79470                                      Pack, Recycle
#
#                                                       10               11  \
# 0                            Clean - Pot & Lid - Recycle             Asda
# 1                                                               Unbranded
# 2                                                                   Tesco
# 3                                                                   Tesco
# 4                                                                Mug Shot
# ...                                                  ...              ...
# 79466  Recycle me, This bottle is made from 100% recy...  Highland Spring
# 79467                                                            Gilfresh
# 79468                           Rinse / Lid on - Recycle          Patak's
# 79469                        Clean - Jar & Lid - Recycle             Asda
# 79470                                                                Asda
#
#                                                       12  \
# 0      Rich and thick, pour over treacle sponge or mi...
# 1
# 2
# 3
# 4      Have a mug shot mmmoment!\nRamp up your lunch ...
# ...                                                  ...
# 79466  A fruity burst of natural strawberry flavour m...
# 79467
# 79468
# 79469
# 79470
#
#                                                       13  \
# 0                                    Double Cream (Milk)
# 1
# 2
# 3      Tomato Purée, Spirit Vinegar, Sugar, Water, Ap...
# 4      Dried Pasta [Durum Wheat Semolina], Natural Fl...
# ...                                                  ...
# 79466  Still Spring Water, Acid (Citric Acid), Natura...
# 79467                                            Carrots
# 79468  Limes (64%), Rapeseed Oil, Salt, Ground Spices...
# 79469  Water, Rapeseed Oil, Soured Cream (Milk) (7%),...
# 79470  Sugar, Water, Maize Starch, Rice Flour, Coconu...
#
#                                                       14  \
# 0
# 1
# 2
# 3      Sweet & tangy, Subtly spiced for a rounded fru...
# 4      Flavour to the Max, Ready in 5 Minutes, Made w...
# ...                                                  ...
# 79466                                         Sugar Free
# 79467                                    Sweet & Crunchy
# 79468  Spicy & Zesty, Chilli rating - Hot - 3, No Art...
# 79469  Creamy and mild, perfect for dunking and dippi...
# 79470
#
#                                      15 16    17
# 0      Do Not Freeze, Keep Refrigerated     None
# 1                                           None
# 2                                           None
# 3                                           None
# 4                                           None
# ...                                 ... ..   ...
# 79466                                       None
# 79467                 Keep Refrigerated     None
# 79468                                       None
# 79469                                       None
# 79470                                       None
#
# [79471 rows x 18 columns]

# %%
backup = out_df

# %%
out_df=out_df.iloc[:, :-1]
out_df.columns = columns

# %%
out_df
# Out:
#                name            gtin  isDelete        date                 pl1  \
# 0       4663234.xml   5020379124584         1  2017-08-18
# 1      10635409.xml   5000299618394         1  2022-08-04
# 2      12659917.xml   5702017600208         0  2023-12-08  Household & Garden
# 3      12461053.xml   5060427350343         0  2024-01-08  Skin and Hair Care
# 4      10036086.xml   5020379166355         1  2021-12-22
# ...             ...             ...       ...         ...                 ...
# 15080  10340743.xml  03026981373619         1  2022-05-10
# 15081   8431139.xml   5020379144605         1  2020-10-26
# 15082  10296462.xml   0000000462259         1  2022-03-21
# 15083  10404930.xml   5010525194233         1  2022-05-03
# 15084   5947214.xml   5020379139939         1  2018-05-25
#
#                                pl2                  pl3  \
# 0
# 1
# 2                         For Kids                 Toys
# 3      Soaps, Deodorants & Bathing  Soap & Liquid Soaps
# 4
# ...                            ...                  ...
# 15080
# 15081
# 15082
# 15083
# 15084
#
#                                              description allergyAdvice  \
# 0
# 1
# 2      LEGO Creator 3in1 Hamster Wheel Animal Toy Set...
# 3                     Kids Stuff Blue Foaming Soap 225ml
# 4
# ...                                                  ...           ...
# 15080
# 15081
# 15082
# 15083
# 15084
#
#       recycling                   recycling_other      brands marketing  \
# 0
# 1
# 2                                                        Lego
# 3                Recycle when empty. Do not crush  Kids Stuff
# 4
# ...         ...                               ...         ...       ...
# 15080
# 15081
# 15082
# 15083
# 15084
#
#                                              ingredients  \
# 0
# 1
# 2
# 3      Aqua (Water), Butane, Isobutane, Propane, Trie...
# 4
# ...                                                  ...
# 15080
# 15081
# 15082
# 15083
# 15084
#
#                                                 features storage preserves
# 0
# 1
# 2
# 3      Blue Foaming Soap, Fun Fruity Fragrance, Gentl...
# 4
# ...                                                  ...     ...       ...
# 15080
# 15081
# 15082
# 15083
# 15084
#
# [15085 rows x 17 columns]

# %% [markdown]
# Extract and Process Only the Missing XML Files

# %%
# Check each cell in the selected columns to see if it contains a list
list_rows = out_df[[
    'description',
    'allergyAdvice',
    'recycling',
    'recycling_other',
    'brands',
    'marketing',
    'ingredients',
    'features',
    'storage',
    'preserves'
]].applymap(lambda x: isinstance(x, list)).any(axis=1)

# Display rows that contain lists
rows_with_lists = out_df[list_rows]
print(rows_with_lists)
# Out:
#                name            gtin  isDelete        date                 pl1  \
# 287    12670235.xml   4060800304353         0  2023-12-15              Drinks
# 297    12670525.xml   5060963011906         0  2023-12-18    Ready Made Foods
# 380    12660701.xml   0811670032174         0  2024-03-03       Dairy & Bread
# 683    12617751.xml   5000101514265         0  2024-02-20  Skin and Hair Care
# 847    12684373.xml   5000393171689         0  2023-12-28         Off Licence
# ...             ...             ...       ...         ...                 ...
# 14531  12696412.xml   7613036288644         0  2024-01-05                Pets
# 14581  12677084.xml  03574661332505         0  2023-12-21  Skin and Hair Care
# 14610  12677110.xml   5000171058539         0  2023-12-19             Grocery
# 14814  12687005.xml   5060078180375         0  2024-01-03         Off Licence
# 14983  12677108.xml   5000171058485         0  2023-12-19             Grocery
#
#                                pl2                                pl3  \
# 287              Carbonated Drinks  Other Flavoured Carbonated Drinks
# 297                          Meals                              Other
# 380            White Bread & Rolls                              Other
# 683    Soaps, Deodorants & Bathing                              Other
# 847          Cigarettes & Lighters                Other Smoker's Item
# ...                            ...                                ...
# 14531                          Dog                  Complete Dog Food
# 14581     Female Health and Beauty                           Skincare
# 14610                   Other Tins      Pilchards/ Mackerel/ Sardines
# 14814             Champagne & Rose                    Rose Wine Other
# 14983                   Other Tins      Pilchards/ Mackerel/ Sardines
#
#                                              description  \
# 287                                        7UP 8 x 330ml
# 297                        The Gym Kitchen Chicken Tikka
# 380    Ocean's Halo 12 Organic Spring Roll Rice Wraps...
# 683    Cussons Carex Limited Edition Peony & Blossom ...
# 847          Vuse Crushed Mint ePen eLiquid Pods 12mg/ml
# ...                                                  ...
# 14531  Bakers Adult with Tasty Beef & Country Vegetab...
# 14581  NEUTROGENA Clear & Defend 2% Salicylic Acid Fa...
# 14610  John West Mackerel Fillets in Smokehouse BBQ S...
# 14814        Blossom Hill Crisp & Fruity Rosé Wine 750ml
# 14983       John West Mackerel Fillets in Olive Oil 115g
#
#                              allergyAdvice  \
# 287
# 297        Milk, Contains, Wheat, Contains
# 380
# 683
# 847
# ...                                    ...
# 14531
# 14581
# 14610                       Fish, Contains
# 14814  Sulphur Dioxide/Sulphites, Contains
# 14983                       Fish, Contains
#
#                                                recycling recycling_other  \
# 287    Pack, Recycle with bags at large supermarket -...              []
# 297                                        Pack, Recycle
# 380                                                                   []
# 683                             Whole Packaging, Recycle              []
# 847                                                                   []
# ...                                                  ...             ...
# 14531  Bag, Recycle with bags at large supermarket - ...              []
# 14581
# 14610                        Whole Packaging, Recyclable              []
# 14814                                                                 []
# 14983                        Whole Packaging, Recyclable              []
#
#                 brands                                          marketing  \
# 287                7UP
# 297    The Gym Kitchen                                                 []
# 380       Ocean's Halo  That’s a wrap! Use our Ocean’s Halo Rice Paper...
# 683            Cussons  Carex Peony and Blossom Bath and Shower with f...
# 847               Vuse
# ...                ...                                                ...
# 14531           Bakers  Our recipe has been made with a variety of ten...
# 14581       Neutrogena  NEUTROGENA® Clear & Defend 2% Salicylic Acid F...
# 14610        John West
# 14814     Blossom Hill  Ever wondered what sunshine tastes like? This ...
# 14983        John West
#
#                                              ingredients  \
# 287    Carbonated Water, Sugar, Acids (Citric Acid, M...
# 297    Tomato Tortilla Wrap [Wheat Flour (Wheat Flour...
# 380     Organic Rice Flour, Organic Tapioca Starch, Salt
# 683    Aqua, Sodium Laureth Sulfate, Cocamidopropyl B...
# 847
# ...                                                  ...
# 14531  Cereals (Wholegrains* 55%), Meat and Animal De...
# 14581                                                 []
# 14610  Mackerel Fillets (Fish) (52%; Ocean of Catch: ...
# 14814
# 14983  Mackerel Fillets (Fish) (Ocean of Catch: North...
#
#                                                 features            storage  \
# 287    Refreshing Lemon & Lime Taste, Fridge Filler, ...
# 297    Food to Fuel, No Mayo, High in Protein, 24g Pr...  Keep Refrigerated
# 380                                                   []
# 683    Dermatologically tested, 100% Soap free, Maint...
# 847
# ...                                                  ...                ...
# 14531  Recipe Using Superfoods, 100% Complete, With N...
# 14581
# 14610               Skinless & Boneless, High in Omega 3
# 14814                                                 []
# 14983               Skinless & Boneless, High in Omega 3
#
#       preserves
# 287
# 297
# 380
# 683
# 847
# ...         ...
# 14531
# 14581
# 14610
# 14814
# 14983
#
# [115 rows x 17 columns]
# C:\Users\Jack\AppData\Local\Temp\ipykernel_20248\2266683368.py:13: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ]].applymap(lambda x: isinstance(x, list)).any(axis=1)

# %%
# Replace empty lists with empty strings across all columns in the DataFrame
out_df = out_df.applymap(lambda x: '' if x == [] else x)
# Out:
# C:\Users\Jack\AppData\Local\Temp\ipykernel_20248\1488360103.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   out_df = out_df.applymap(lambda x: '' if x == [] else x)

# %%
# Apply the transformations
out_df = out_df.fillna('')
out_df['text'] = out_df[[
    'description',
    'allergyAdvice',
    'recycling',
    'recycling_other',
    'brands',
    'marketing',
    'ingredients',
    'features',
    'storage',
    'preserves']].agg(' '.join, axis=1)

out_df.loc[out_df['isDelete'] == 1, 'text'] = ''
out_df['text'] = out_df['text'].str.lower()
out_df['text'] = out_df['text'].str.replace('\n', '', regex=True)

print("Data transformation completed.")
out_df
# Out:
# Data transformation completed.
#                name            gtin  isDelete        date                 pl1  \
# 0       4663234.xml   5020379124584         1  2017-08-18
# 1      10635409.xml   5000299618394         1  2022-08-04
# 2      12659917.xml   5702017600208         0  2023-12-08  Household & Garden
# 3      12461053.xml   5060427350343         0  2024-01-08  Skin and Hair Care
# 4      10036086.xml   5020379166355         1  2021-12-22
# ...             ...             ...       ...         ...                 ...
# 15080  10340743.xml  03026981373619         1  2022-05-10
# 15081   8431139.xml   5020379144605         1  2020-10-26
# 15082  10296462.xml   0000000462259         1  2022-03-21
# 15083  10404930.xml   5010525194233         1  2022-05-03
# 15084   5947214.xml   5020379139939         1  2018-05-25
#
#                                pl2                  pl3  \
# 0
# 1
# 2                         For Kids                 Toys
# 3      Soaps, Deodorants & Bathing  Soap & Liquid Soaps
# 4
# ...                            ...                  ...
# 15080
# 15081
# 15082
# 15083
# 15084
#
#                                              description allergyAdvice  \
# 0
# 1
# 2      LEGO Creator 3in1 Hamster Wheel Animal Toy Set...
# 3                     Kids Stuff Blue Foaming Soap 225ml
# 4
# ...                                                  ...           ...
# 15080
# 15081
# 15082
# 15083
# 15084
#
#       recycling                   recycling_other      brands marketing  \
# 0
# 1
# 2                                                        Lego
# 3                Recycle when empty. Do not crush  Kids Stuff
# 4
# ...         ...                               ...         ...       ...
# 15080
# 15081
# 15082
# 15083
# 15084
#
#                                              ingredients  \
# 0
# 1
# 2
# 3      Aqua (Water), Butane, Isobutane, Propane, Trie...
# 4
# ...                                                  ...
# 15080
# 15081
# 15082
# 15083
# 15084
#
#                                                 features storage preserves  \
# 0
# 1
# 2
# 3      Blue Foaming Soap, Fun Fruity Fragrance, Gentl...
# 4
# ...                                                  ...     ...       ...
# 15080
# 15081
# 15082
# 15083
# 15084
#
#                                                     text
# 0
# 1
# 2      lego creator 3in1 hamster wheel animal toy set...
# 3      kids stuff blue foaming soap 225ml   recycle w...
# 4
# ...                                                  ...
# 15080
# 15081
# 15082
# 15083
# 15084
#
# [15085 rows x 18 columns]

# %%
out_df["text_tsvector"] = ""

# %% [markdown]
# Insert Data into PostgreSQL

# %%
import psycopg2
from psycopg2.extras import execute_values

def insert_data_without(df):
    try:
        conn = psycopg2.connect(**db_config)
        cursor = conn.cursor()
        
        # Insert query without tsvector_data, to be calculated in PostgreSQL later
        insert_query = """
            INSERT INTO brandbankxml (xml_id, gtin, "isDelete", date, pl1, pl2, pl3, description, "allergyAdvice", 
                                      recycling, recycling_other, brands, marketing, ingredients, features, 
                                      storage, preserves, text, text_tsvector)
            VALUES %s
            ON CONFLICT (xml_id) DO NOTHING
        """
        
        # Prepare the data to be inserted
        data = df.to_records(index=False).tolist()

        # Use execute_values to perform a bulk insert
        execute_values(cursor, insert_query, data)
        
        conn.commit()
        cursor.close()
        conn.close()
        print(f"Inserted {len(data)} new records into the database.")
    except Exception as e:
        print(f"Error inserting data into PostgreSQL: {e}")

# %%
insert_data_without(out_df)
# Out:
# Inserted 15085 new records into the database.

# %%
def update_tsvector_column():
    try:
        conn = psycopg2.connect(**db_config)
        cursor = conn.cursor()
        
        # SQL command to populate tsvector_data column based on the text column
        update_query = """
            UPDATE brandbankxml
            SET text_tsvector = to_tsvector('english', text)
            WHERE text_tsvector IS NULL OR text_tsvector = '';
        """
        
        cursor.execute(update_query)
        conn.commit()
        cursor.close()
        conn.close()
        print("tsvector_data column updated successfully.")
    except Exception as e:
        print(f"Error updating text_tsvector column: {e}")

# %%
# Then, update the tsvector column
update_tsvector_column()
# Out:
# tsvector_data column updated successfully.

# %%
max_xml_id_in_db = get_highest_xml_id()
max_xml_id_in_db
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 max_xml_id_in_db = get_highest_xml_id()
#       2 max_xml_id_in_db
#
# NameError: name 'get_highest_xml_id' is not defined

# %%
out_df
# Out:
#                name           gtin  isDelete        date                 pl1  \
# 0      13104033.xml  5050854280047         0  2024-08-01       Dairy & Bread
# 1      12764831.xml       00389976         0  2024-01-29  Household & Garden
# 2      13740753.xml  5059697755262         0  2024-09-17  Household & Garden
# 3      13234327.xml  5057753923136         0  2024-07-08             Grocery
# 4      13033043.xml  5050665050136         0  2024-05-20    Ready Made Foods
# ...             ...            ...       ...         ...                 ...
# 79466  12967228.xml  5010459000891         0  2024-04-12              Drinks
# 79467  13028180.xml  5060206743861         0  2024-04-09  Fruit & Vegetables
# 79468  12947527.xml  5011308000208         0  2024-04-08             Grocery
# 79469  13420819.xml  5054781461234         0  2024-07-29             Grocery
# 79470  12832749.xml  5063089158609         0  2024-03-07             Grocery
#
#                            pl2                        pl3  \
# 0                 Milk & Cream                Fresh Cream
# 1                       Plants                Cut Flowers
# 2                    Utilities                      Other
# 3          Sauces & Condiments  Other Sauces & Condiments
# 4                        Meals                      Other
# ...                        ...                        ...
# 79466                    Water               Still Waters
# 79467          Core Vegetables                    Carrots
# 79468  Speciality/Ethnic Foods      Indian Cooking Sauces
# 79469      Sauces & Condiments                       Dips
# 79470     Mixes, Jelly & Flour                      Other
#
#                                              description  \
# 0                          Asda Fresh Double Cream 250ml
# 1                                        Beautiful Smile
# 2      Tesco F&I 400TC CTN Tencel Flexi Fitted Sheet ...
# 3                          Tesco Fruity Brown Sauce 445g
# 4           Mug Shot Max Roast Chicken Flavour Pasta 68g
# ...                                                  ...
# 79466  Highland Spring Strawberry Still Spring Water ...
# 79467                  Gilfresh Family Grown Carrots 1kg
# 79468                       Patak's Hot Lime Pickle 283g
# 79469                       Asda Sour Cream & Chive 290g
# 79470                BAKE by ASDA Blue Sprinkles Mix 70g
#
#                                            allergyAdvice  \
# 0                                         Milk, Contains
# 1
# 2
# 3
# 4      Barley, Contains, Cereals Containing Gluten, M...
# ...                                                  ...
# 79466
# 79467
# 79468  Mustard, Contains, Nuts, May Contain, Peanuts,...
# 79469                     Eggs, Contains, Milk, Contains
# 79470  Milk, Contains, Nuts, May Contain, Peanuts, Ma...
#
#                                                recycling  \
# 0                                   Film, Do Not Recycle
# 1
# 2
# 3                                Bottle, Widely Recycled
# 4      Lid, Do Not Recycle, Pot, Recycle, Sleeve, Rec...
# ...                                                  ...
# 79466
# 79467  Film, Plastic - Widely Recycled, Pack, Recycle...
# 79468
# 79469
# 79470                                      Pack, Recycle
#
#                                          recycling_other           brands  \
# 0                            Clean - Pot & Lid - Recycle             Asda
# 1                                                               Unbranded
# 2                                                                   Tesco
# 3                                                                   Tesco
# 4                                                                Mug Shot
# ...                                                  ...              ...
# 79466  Recycle me, This bottle is made from 100% recy...  Highland Spring
# 79467                                                            Gilfresh
# 79468                           Rinse / Lid on - Recycle          Patak's
# 79469                        Clean - Jar & Lid - Recycle             Asda
# 79470                                                                Asda
#
#                                                marketing  \
# 0      Rich and thick, pour over treacle sponge or mi...
# 1
# 2
# 3
# 4      Have a mug shot mmmoment!\nRamp up your lunch ...
# ...                                                  ...
# 79466  A fruity burst of natural strawberry flavour m...
# 79467
# 79468
# 79469
# 79470
#
#                                              ingredients  \
# 0                                    Double Cream (Milk)
# 1
# 2
# 3      Tomato Purée, Spirit Vinegar, Sugar, Water, Ap...
# 4      Dried Pasta [Durum Wheat Semolina], Natural Fl...
# ...                                                  ...
# 79466  Still Spring Water, Acid (Citric Acid), Natura...
# 79467                                            Carrots
# 79468  Limes (64%), Rapeseed Oil, Salt, Ground Spices...
# 79469  Water, Rapeseed Oil, Soured Cream (Milk) (7%),...
# 79470  Sugar, Water, Maize Starch, Rice Flour, Coconu...
#
#                                                 features  \
# 0
# 1
# 2
# 3      Sweet & tangy, Subtly spiced for a rounded fru...
# 4      Flavour to the Max, Ready in 5 Minutes, Made w...
# ...                                                  ...
# 79466                                         Sugar Free
# 79467                                    Sweet & Crunchy
# 79468  Spicy & Zesty, Chilli rating - Hot - 3, No Art...
# 79469  Creamy and mild, perfect for dunking and dippi...
# 79470
#
#                                 storage preserves  \
# 0      Do Not Freeze, Keep Refrigerated
# 1
# 2
# 3
# 4
# ...                                 ...       ...
# 79466
# 79467                 Keep Refrigerated
# 79468
# 79469
# 79470
#
#                                                     text text_tsvector
# 0      asda fresh double cream 250ml milk, contains f...
# 1                      beautiful smile    unbranded
# 2      tesco f&i 400tc ctn tencel flexi fitted sheet ...
# 3      tesco fruity brown sauce 445g  bottle, widely ...
# 4      mug shot max roast chicken flavour pasta 68g b...
# ...                                                  ...           ...
# 79466  highland spring strawberry still spring water ...
# 79467  gilfresh family grown carrots 1kg  film, plast...
# 79468  patak's hot lime pickle 283g mustard, contains...
# 79469  asda sour cream & chive 290g eggs, contains, m...
# 79470  bake by asda blue sprinkles mix 70g milk, cont...
#
# [79471 rows x 19 columns]
