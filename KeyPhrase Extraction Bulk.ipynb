# %% [markdown]
# Preprocess data

# %%
import pandas as pd
from tqdm import tqdm
import csv

# %%
brandbankExtract = r'Data\Bulk Extract.csv'

# %%
df = pd.read_csv(brandbankExtract)
df
# Out:
#                name           gtin  isDelete        date                 pl1  \
# 0        905597.xml            185         0  2010-08-16       Dairy & Bread
# 1        643362.xml            246         0  2006-02-24                Deli
# 2        905600.xml            260         0  2010-08-16       Dairy & Bread
# 3        980223.xml            581         0  2011-02-28  Fruit & Vegetables
# 4       8445550.xml           6491         0  2020-10-14  Fruit & Vegetables
# ...             ...            ...       ...         ...                 ...
# 157840  2375232.xml  9857423623122         0  2014-08-12         Meat & Fish
# 157841  5596613.xml  9993510358956         0  2018-03-19         Meat & Fish
# 157842  4607178.xml  9999999999994         0  2017-07-20         Meat & Fish
# 157843  6771345.xml  9999999999994         0  2019-03-06         Meat & Fish
# 157844  6921507.xml  9999999999994         0  2020-01-09         Meat & Fish
#
#                         pl2                  pl3  \
# 0       White Bread & Rolls                Other
# 1               Unallocated          Unallocated
# 2       White Bread & Rolls  French Bread/ Rolls
# 3            Salad Products              Peppers
# 4                    Apples         Other Apples
# ...                     ...                  ...
# 157840           Fresh Fish               Salmon
# 157841            Shellfish      Other Shellfish
# 157842                 Lamb           Other Lamb
# 157843       Reformed Meats              Burgers
# 157844     Chicken & Turkey         Other Turkey
#
#                                               description  \
# 0                         Waitrose Fig & Raisin Loaf 400g
# 1                       WR Gingerbread biscuit chick each
# 2                          Waitrose Petit Parisienne 290g
# 3                           Waitrose Loose Yellow Peppers
# 4                                   Asda Pink Lady Apples
# ...                                                   ...
# 157840        Wrights of Howth Sliced Smoked Salmon 400gr
# 157841          Morrisons Fresh Live Scottish Mussels 1kg
# 157842                     Glenmór Lamb Carvery Shoulders
# 157843  Hogan's Farm 12 Buffalo Turkey Burgers and 12 ...
# 157844                  Hogan's 5 Star Half Turkey Breast
#
#                               allergyAdvice recycling recycling_other  \
# 0                                       NaN       NaN             NaN
# 1                                       NaN       NaN             NaN
# 2                                       NaN       NaN             NaN
# 3                                       NaN       NaN             NaN
# 4                                       NaN       NaN             NaN
# ...                                     ...       ...             ...
# 157840                                  NaN       NaN             NaN
# 157841                                  NaN       NaN             NaN
# 157842                                  NaN       NaN             NaN
# 157843  Sulphur Dioxide/Sulphites, Contains       NaN             NaN
# 157844                   Wheat, May Contain       NaN             NaN
#
#                   brands marketing  \
# 0               Waitrose       NaN
# 1                    NaN       NaN
# 2               Waitrose       NaN
# 3               Waitrose       NaN
# 4                   Asda       NaN
# ...                  ...       ...
# 157840  Wrights of Howth       NaN
# 157841         Morrisons       NaN
# 157842           Glenmór       NaN
# 157843      Hogan's Farm       NaN
# 157844           Hogan's       NaN
#
#                                               ingredients  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 157840                Salmon, Salmo Salar Salt, Oak Smoke
# 157841                                                NaN
# 157842                                                NaN
# 157843  Turkey (75%), Buffalo Glaze (Acidity Regulator...
# 157844  Turkey Breast Meat, Salt, Stabilisers (Di, Tri...
#
#                                                  features  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 157840                                                NaN
# 157841                                                NaN
# 157842                                Irish country meats
# 157843  High in protein, Low in fat, Fresh class A tur...
# 157844                                                NaN
#
#                                                   storage preserves
# 0                                                     NaN       NaN
# 1                                                     NaN       NaN
# 2                                                     NaN       NaN
# 3                                                     NaN       NaN
# 4                                                     NaN       NaN
# ...                                                   ...       ...
# 157840                                  Keep Refrigerated       NaN
# 157841  Not Suitable for Home Freezing, Keep Refrigerated       NaN
# 157842                                                NaN       NaN
# 157843                                                NaN       NaN
# 157844                                  Keep Refrigerated       NaN
#
# [157845 rows x 17 columns]

# %%
df=df.fillna('')
df = df[df['isDelete'] != 1]
df['text'] = df[[
    'description',
    'allergyAdvice',
    'recycling',
    'recycling_other',
    'brands',
    'marketing',
    'ingredients',
    'features',
    'storage',
    'preserves']].agg(' '.join, axis=1)


df['text'] = df['text'].str.lower()
df.head()
# Out:
#           name  gtin  isDelete        date                 pl1  \
# 0   905597.xml   185         0  2010-08-16       Dairy & Bread
# 1   643362.xml   246         0  2006-02-24                Deli
# 2   905600.xml   260         0  2010-08-16       Dairy & Bread
# 3   980223.xml   581         0  2011-02-28  Fruit & Vegetables
# 4  8445550.xml  6491         0  2020-10-14  Fruit & Vegetables
#
#                    pl2                  pl3  \
# 0  White Bread & Rolls                Other
# 1          Unallocated          Unallocated
# 2  White Bread & Rolls  French Bread/ Rolls
# 3       Salad Products              Peppers
# 4               Apples         Other Apples
#
#                          description allergyAdvice recycling recycling_other  \
# 0    Waitrose Fig & Raisin Loaf 400g
# 1  WR Gingerbread biscuit chick each
# 2     Waitrose Petit Parisienne 290g
# 3      Waitrose Loose Yellow Peppers
# 4              Asda Pink Lady Apples
#
#      brands marketing ingredients features storage preserves  \
# 0  Waitrose
# 1
# 2  Waitrose
# 3  Waitrose
# 4      Asda
#
#                                                text
# 0  waitrose fig & raisin loaf 400g    waitrose
# 1        wr gingerbread biscuit chick each
# 2   waitrose petit parisienne 290g    waitrose
# 3    waitrose loose yellow peppers    waitrose
# 4                asda pink lady apples    asda

# %% [markdown]
# RAKE_NLTK

# %%
from rake_nltk import Rake
import nltk
r = Rake()

# %%
def get_num_words(row):
    return len(str(row['Phrase']).split())

def get_perc_phrase(row,total):
    return (float(row['Score'])/total*100)

# %%
def get_Rake_phrases(df):
    r = Rake()
    r.extract_keywords_from_sentences(df['text'])
    phrases=r.get_ranked_phrases_with_scores()
    df = pd.DataFrame(phrases, columns = ['Rank', 'Phrase'])
    df['Phrase'] = df['Phrase'].str.strip()
    phrase_counts = df['Phrase'].value_counts()
    phrase_counts = phrase_counts.reset_index()
    phrase_counts.columns=['Phrase','Score']
    phrase_counts['Length'] = phrase_counts.apply (lambda row: get_num_words(row), axis=1)
    phrase_counts=phrase_counts.loc[phrase_counts['Length'] <=6]
    total = float(phrase_counts['Score'].sum())
    phrase_counts['Perc'] = phrase_counts.apply (lambda row: get_perc_phrase(row,total), axis=1)
    return phrase_counts

# %%
df_raked = get_Rake_phrases(df)
#phrase_counts.to_csv(r'C:\Users\Clamfighter\Documents\GitHub\NLP\Impact Score Key Phrase\Extracted Phrases\Rake NLTK\Brandbank Latest Phrase Extraction.csv',index = False)

# %%
df_raked
# Out:
#                                                 Phrase  Score  Length  \
# 0                                             contains  46195       1
# 1                                                 free  28158       1
# 2                                          may contain  27941       2
# 3                                             suitable  27103       1
# 4                                                 salt  25606       1
# ...                                                ...    ...     ...
# 559954                                 something big 8      1       3
# 559955                   refreshingly remarkable treat      1       3
# 559956                naturally fresh deo crystal roll      1       5
# 559957                                 salt ), vinegar      1       3
# 559958  fulfil chocolate hazelnut whip flavour vitamin      1       6
#
#             Perc
# 0       1.027913
# 1       0.626561
# 2       0.621732
# 3       0.603085
# 4       0.569774
# ...          ...
# 559954  0.000022
# 559955  0.000022
# 559956  0.000022
# 559957  0.000022
# 559958  0.000022
#
# [507044 rows x 4 columns]

# %%
phrase_count=[]

df_phraseCount = df_raked.loc[df_raked['Score'] != 1] #filters Score of 1 out. will be added back in later
phrases = df_phraseCount['Phrase']
text = df['text']
for phrase in tqdm(phrases): #find number of phrases for all strings
    phrase_count.append(sum(phrase in s for s in text))
phrase_count
# Out:
#  10%|▉         | 5088/51606 [01:27<12:53, 60.16it/s]

# %%
df_phraseCount['Count'] = phrase_count
df_phraseCount.drop(['Score','Length','Perc'],axis=1, inplace=True)
df_out = df_raked.merge(df_phraseCount, on='Phrase', how='left')
df_out.fillna(1,inplace=True)
df_out
# Out:
# C:\Users\admin_1878\AppData\Local\Temp\ipykernel_11008\2573982755.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_phraseCount['Count'] = phrase_count
# C:\Users\admin_1878\AppData\Local\Temp\ipykernel_11008\2573982755.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_phraseCount.drop(['Score','Length','Perc'],axis=1, inplace=True)
#                                      Phrase  Score  Length      Perc    Count
# 0                                  contains  46090       1  1.043119  46566.0
# 1                                      free  27964       1  0.632888  28091.0
# 2                               may contain  27856       2  0.630443  14558.0
# 3                                  suitable  26888       1  0.608535  32327.0
# 4                                     sugar  25511       1  0.577371  33710.0
# ...                                     ...    ...     ...       ...      ...
# 500458                  best fighting units      1       3  0.000023      1.0
# 500459  piers morgan unbranded piers morgan      1       5  0.000023      1.0
# 500460         extremely perilous christmas      1       3  0.000023      1.0
# 500461                    trifles unbranded      1       2  0.000023      1.0
# 500462                holly smale unbranded      1       3  0.000023      1.0
#
# [500463 rows x 5 columns]

# %%
#df_out.to_csv(r'out_lower.csv',index = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df_out.to_csv(r'out_lower.csv',index = False)
#
# NameError: name 'df_out' is not defined
