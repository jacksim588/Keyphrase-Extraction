# %% [markdown]
# Data Load

# %%
import pandas as pd

# %%
df_old = pd.read_csv(r'Extracted Phrases\Rake NLTK\Oldest Phrase Extraction.csv')
df_old
# Out:
#                           Phrase  Score  Length      Perc    Count
# 0                       contains  19980       1  1.086187  19295.0
# 1                    may contain  13021       2  0.707870   6827.0
# 2                           salt  11870       1  0.645297  13396.0
# 3                       suitable  11652       1  0.633446  14411.0
# 4                          sugar  11586       1  0.629858  14156.0
# ...                          ...    ...     ...       ...      ...
# 411798  sodium carbonate ], salt      1       4  0.000054      1.0
# 411799      shallot ), red onion      1       4  0.000054      1.0
# 411800   cinnamon ), citric acid      1       4  0.000054      1.0
# 411801       bali tropical drink      1       3  0.000054      1.0
# 411802          hake ), minerals      1       3  0.000054      1.0
#
# [411803 rows x 5 columns]

# %%
df_new = pd.read_csv(r'Extracted Phrases\Rake NLTK\Latest Phrase Extraction.csv')
df_new
# Out:
#                                 Phrase  Score  Length      Perc   Count
# 0                             contains   7928       1  1.076919  8395.0
# 1                          may contain   5579       2  0.757837  2845.0
# 2                             suitable   5158       1  0.700650  6210.0
# 3                                 salt   4711       1  0.639930  5642.0
# 4                                sugar   4652       1  0.631916  6089.0
# ...                                ...    ...     ...       ...     ...
# 159696               1 %), dried herbs      1       4  0.000136     1.0
# 159697              1 %), skimmed cows      1       4  0.000136     1.0
# 159698  parsley ), natural flavourings      1       4  0.000136     1.0
# 159699       tasty honey mustard sauce      1       4  0.000136     1.0
# 159700                              "[      1       1  0.000136     1.0
#
# [159701 rows x 5 columns]

# %% [markdown]
# Find New Key Phrases

# %%
list(set(df_new['Phrase']) - set(df_old['Phrase']))
# Out:
# ['pure wholegrain oats bursting',
#  'consumed throughout',
#  'shine custard helps reduce hair bulk',
#  'ground turmeric heat',
#  'rimmel london introduces',
#  '5kg nuts',
#  'flexitol heel balm',
#  'classic streetfood',
#  'mellow malts',
#  'partners sliced runner beans 160g',
#  'every cat',
#  'ci 74160 helps whiten',
#  'cooked egg tagliatelle',
#  'brand marketing “ cîroc',
#  'cats aged 7 +, specially formulated',
#  'enjoy carlsberg nordic',
#  'little peppa pig fans',
#  '37 m2 ). eliminates odours',
#  'sized dogs',
#  'may contain morrisons purple haze',
#  '5 woods',
#  'coconut miracle oil air dry cream',
#  '61 calories per serving',
#  'soya lecithins )) vegetarian',
#  'contains mude ‘ work',
#  'simple shampoo',
#  'pure maple syrup pure canadian',
#  'younger ex',
#  'lime dipping sauce',
#  'fine green tea leaves blended',
#  'chicory root inulin',
#  'e300 ), yeast',
#  'original salad dressing 210 ml mustard',
#  'eight specialised microfibre cleaning',
#  'sesame oil keep frozen',
#  'co op pumpkin seeds 100g nuts',
#  'ginger ale 1l bottle',
#  'oldest vines',
#  'premium liquids',
#  'fat lean',
#  'microplastic marine litter',
#  'oreal colour protect conditioner',
#  'allergens ....), helps',
#  'try making delicious fruit cocktail cake',
#  'real butter breadcrumbs',
#  'vanilla flavouring ), dark chocolate',
#  'puffed wheat 160g barley',
#  'get everyone eating tasty',
#  'smaller handle',
#  'larger dogs enriched',
#  'cheesemongers',
#  '1 usb charger',
#  'combine aquafresh extra fresh daily mouthwash',
#  'latest wonder',
#  'tri sodium citrate ), antioxidant',
#  'ci 42090 body',
#  'lighter mayonnaise formulated',
#  'reaction products',
#  'whitening action',
#  'classic cereal bar',
#  'outdoor balconies',
#  'printer used images printed',
#  'refreshing fix',
#  'key lime green',
#  'omega 3 smoked mackerel',
#  'even waterproof mascara !,',
#  'cleansing formula removes dust',
#  'yet recycled waitrose pineapple jam',
#  '8x jumbone ™ mini beef',
#  '7 %), whole grain wheat',
#  'spinach pie 170g eggs',
#  'long lasting blonde hair colour',
#  'limonene repairs',
#  'parfum pump format',
#  'special rosé cava made',
#  'coastal escape 20ml ambi pur',
#  '2015 global cheese awards',
#  'pure pressed tomato juice',
#  'sicilian oregano 2 x 218g',
#  'creamy handmade cheese',
#  'exract keep refrigerated',
#  'produced using timehonoured craftsmanship',
#  '18 grams',
#  'sunflower oil ), mozzarella cheese 16',
#  'looks boiled',
#  'potassium benzoate ), sweetened',
#  'cooperatives receive benefits',
#  'lighter salad dressing',
#  'truffle flavour ], plant based',
#  'mental clarity',
#  '4 %, salt flavour',
#  'corrects',
#  'bristled pick',
#  'stewart brewing',
#  'msg maize',
#  'waitrose soft agen prunes 270g bag',
#  'diced pork',
#  'cave cellars',
#  'signature serve',
#  'gently baked whole fresh fruit',
#  'classified according',
#  'world class medical teams',
#  'golden syrup sticky pudding cake wheat',
#  '18 months nutmeg designed',
#  'nurtures hair leaving',
#  'fight visible signs',
#  'mini strawberry napoleons',
#  'sodium gluconate ), citric acid',
#  'contains waitrose cod',
#  '240 m2',
#  'pearl drops scale',
#  'malted bread keep refrigerated',
#  '2 %), cassava extract 100',
#  'widely recycled dale farm yogurt',
#  '240 led warm white pack unbranded',
#  '35ml smirnoff',
#  'ready single bar 22g barley',
#  'grimsby',
#  'year 8 multi',
#  'happy grove',
#  'retinyl acetate ), sugar',
#  'lactic acid ), b vitamins',
#  'wash 500ml sulphur dioxide',
#  'volumises curly hair',
#  'eucalyptus dunnii leaves extract',
#  'factory powered',
#  'help prevent heat damage',
#  '44in',
#  'sensitive sun lotion spf50 200ml bottle',
#  'since 2008',
#  'coors lager 710ml barley',
#  'energizer ® advanced 9v battery',
#  'balanced minerals purina one coat',
#  '24 %), vitamin c apple',
#  'soap making expertise',
#  'turkey pieces',
#  'salt ], whitefish',
#  'nutrients shoot growth',
#  'deliciously creamy dairy',
#  'bitter sweet cliffhanger finale',
#  'n twist',
#  'advanced led refill indicator',
#  'ballymena beef',
#  '3ml sally hansen dry',
#  '... zesty orange',
#  'blister shield plasters',
#  'partners british chicken',
#  '29 %), camomile',
#  '50 %), penne pasta',
#  '390g size loaf',
#  'skin brightening hydrogel eye mask',
#  'swollen breasts',
#  'fledged electric shaver',
#  'bottle contains 6 x 150ml servings',
#  'lavandin oil 0',
#  '87 %), vegetable oil',
#  'full vitality',
#  'dampness',
#  'contains milk ), skimmed milk powder',
#  'bag 200g starbucks smooth',
#  'palm oil keep refrigerated',
#  'yoghurt sound good',
#  'teat end ), smooth texture',
#  'guylian sea shell bar made',
#  'rémy gold',
#  'yet refined',
#  'best results pour bath gel',
#  'last page ...',
#  'pilsner abv',
#  'flavours ... whole grain oat flakes',
#  '1157929',
#  'durum wheat semolina ], potato starch',
#  'milk ), smoked ham cock',
#  'organic dairy people',
#  'premium pink gin',
#  'natural soft matte finish',
#  'tasty sandwich',
#  'farmers give',
#  'bacon tortelloni 300g barley',
#  'dentist recommend',
#  'strongbow cloudy apple cider contains',
#  '25kg co',
#  'саdbury dairy milk fruit',
#  'partners tropical medley 130g waitrose pineapple',
#  'whitstable bay blonde lager 330ml barley',
#  'curb side recycling',
#  '10 ), ci 42090',
#  '90 calorie',
#  'jelly babies 225g',
#  'bourbon process',
#  'contains señorío de chical',
#  'great cola taste',
#  'blending brush',
#  'small remotes',
#  'foundation lasting',
#  'scutellaria root extract',
#  '84 %, tomato paste 5',
#  'market street kiwi',
#  'hair vitamins',
#  'dirt diamond shine',
#  'uk sugar',
#  'flavouring ), garlic powder',
#  '4 %), crystallised ginger',
#  'grown around us',
#  'early motherhood',
#  'contains clearspring clearspring organic wheat',
#  'good deeds',
#  'cauliflower cheese unbranded',
#  'foodstore curry sauce 440g mustard',
#  '179mm deep',
#  'garlic flavoured oil',
#  "?'.'",
#  'face cleanser instantly hydrates',
#  'new one p',
#  'shortcrust pastry base topped',
#  'also contains omega',
#  'smooth melting milk chocolate balls',
#  'natural sea water based nasal spray',
#  'brie de meaux unbranded',
#  'annatto ), flavouring ), palm oil',
#  'classic roast beef',
#  'passionfruit 85g sulphur dioxide',
#  'ci 77742 ), aluminum powder',
#  'made using british beef',
#  '1207074',
#  'heather honey glaze',
#  'forest fruit aromas',
#  'money back *.',
#  'mini truffles',
#  'punch laundry detergents alone cannot maintain',
#  'amazing world foods range',
#  'choc chick',
#  'water 200g waitrose petits pois',
#  'sons ltd invert sugar syrup',
#  'non gluten recipe',
#  'contains strongbow strongbow original cider',
#  'school use',
#  'waitrose potato',
#  'morrisons marzipan 454g almonds',
#  'cadbury white chocolate bag 75g hazelnuts',
#  'soft 1',
#  'recipe layers turkey breast',
#  'recyclable freixenet presented',
#  '16 plant extracts including kola nut',
#  'local aristocracy',
#  'exceptional olives',
#  'chocolate sponge filled',
#  'bombay sapphire gin 1l bottle',
#  'provide hair nourishment deep inside',
#  'prime fish fillet keep frozen',
#  'oven roasted peanuts seasoned',
#  'introducing nutella ® b',
#  'ci 60725 gently cleanses',
#  '1 refill lasts',
#  'recyclable fuller',
#  'recyclable tray check locally',
#  'lipstick duo',
#  'dry shampoos',
#  'finest herbal ingredients including sweet cinnamon',
#  'sea salt great taste 2019',
#  'beer pulling',
#  'getting greener environmental innovation',
#  "beautiful read .'",
#  'cacao chocolate bar 35g nuts',
#  'vegetarian rennet authentic',
#  'cocamidopropylbetaine',
#  'perfect small gift',
#  'hearty malbec',
#  'widely recycled pepsi maximum taste',
#  'fruit shrewsbury',
#  'ingrown hairs combo',
#  '015 %, yucca mojave 0',
#  'simple eye mask contains',
#  'molecular might',
#  'contains morrisons dark chocolate',
#  'rich taste take',
#  'matured cheddar cheese',
#  'conwy',
#  'energizer alkaline aaa battery boasts',
#  'custard 200g',
#  'contains nomadic lovely live yogurt nourished',
#  'swedish cake bakery',
#  "kismet ') 12",
#  'chicken ), 33',
#  'british beef fillet steaks film',
#  'master brewer remixed',
#  'widely recycled asda single cream',
#  'specialists since 1979',
#  'ageing 24 hours moisturiser hydrates',
#  '118 g pork',
#  'oat flakes 16',
#  'wheat noodles',
#  'paul newman tasked',
#  'moisture renew lipstick',
#  'pad stay secure inside',
#  'highly digestible ingredients mean cats',
#  'proper coffee made easy',
#  'recycle vale',
#  'fuze tea mango camomile 400ml celery',
#  'may contain guylian finest belgian chocolates',
#  'mancave anti',
#  'asda basmati white rice 1kg bag',
#  'pack 15',
#  '1 ], yeast extract',
#  'sicilian agriculture',
#  'real olive co',
#  'effectively sooth',
#  'ceylon tea leaves',
#  'contact lenses wearers',
#  'multisurface polish cleaner classic –',
#  'contains market town bakery sultanas',
#  'extra classy',
#  'cream 15g daktarin rapid itch relief',
#  'consuming read',
#  'mini eclairs filled',
#  'waitrose chocolate mini rolls eggs',
#  'coarse cuts',
#  'still tastes amazing',
#  'lipstick directly',
#  'recyclable zodiac carbonated water',
#  'firming action',
#  'recyclable young',
#  'geranio',
#  '1 %): starches',
#  'apple 90g nuts',
#  'firm cannot',
#  'palate light',
#  'c202277',
#  'wasabi peas 200g nuts',
#  'play sandbox',
#  '*** contains naturally occurring sugars',
#  'salt ], white pepper ready',
#  'peel ?,',
#  'scottish raspberry flavour 70cl bottle',
#  'darkest rock star black nail colour',
#  'sulphites ), herb extracts',
#  '1 %), freeze dried strawberry pieces',
#  'bear hug',
#  '600ml gaviscon',
#  'indulgent lotus fragrance indulges',
#  'luxury nail polish',
#  'pigmented mascara',
#  'pears made',
#  'trisodium citrate ), natural flavours',
#  'reducing irritation',
#  '500g tin makes approximately 277 mugs',
#  'sunflower ), herb ], skimmed milk',
#  'winemaker geoffwoolcombe',
#  'op irresistible rioja tempranillo 18',
#  'hair beautifully smooth',
#  'freshly prepare',
#  'uniquely smooth',
#  'cheese flavour potato snack',
#  'yeast tender chicken seasoned',
#  'limescale formula',
#  'competitive skills',
#  'longlasting eyebrow gel prevents',
#  'matte pomade effortlessly glides',
#  'contains sulphites ), dehydrated onion',
#  'complete dry food scientifically formulated',
#  "*' made",
#  'dorsetcereals',
#  'soya ))), rice flour',
#  'duracell plus alkaline c batteries',
#  'morrisons chocolate swiss roll eggs',
#  'contain omega 3',
#  'offers heat protection',
#  'clean refreshing flavour',
#  'reduce limescale',
#  'digital enhanced cordless technology',
#  'kraken black spiced rum',
#  'contains peanut ), salt ], peanuts',
#  'formerly called gillette fusion',
#  'contains willow',
#  'natural botanical drink made',
#  'ingredients corn flour 250g box',
#  'dark ground roast coffee 227g taylors',
#  'fragile gluten',
#  'oetker dark chocolate chips',
#  'added sugar spring water 71',
#  'soaked cotton pad onto painted nails',
#  'also contain specific nutrients',
#  'selected cuts dry cured',
#  '69 %), sugar',
#  'free baby wash',
#  'tesco button brussels sprouts 1kg film',
#  'mosaic elvis juice grapefruit infused ipa',
#  'optimize contact',
#  'day 1 serving',
#  'dog keen',
#  'parfum water resistant',
#  'lovely french fizz',
#  'loyd grossman',
#  'thyme 150g milk',
#  'yeasts complete food',
#  'dish ideas',
#  '64 %), caesar style dressing',
#  'northern ireland carbonated water',
#  'day 60 gummies tesco',
#  '14 %) dressing 150ml sulphur dioxide',
#  'yet recycled waitrose colourful',
#  'information visit www',
#  'clumping odour control cat litter 10l',
#  'producing top quality square sausage',
#  '250 ml shower gel pack',
#  'black carrot juice concentrates',
#  'red wine gravy 350g celery',
#  '3 ingredients needed',
#  'nourishing way',
#  'unique air channels',
#  'green almond',
#  'white pear',
#  'try maille ’',
#  '15 %), british beef',
#  '95 %, 15',
#  'lovely fresh flowery fragrance',
#  'seamless canvas',
#  '9 units edinburgh gin rhubarb',
#  'natural chicken flavour',
#  'op apricot swiss roll eggs',
#  'reducing sugar',
#  'chicken stock pot',
#  'families skin',
#  'roll blue icing 250g film',
#  'game paté',
#  '15sec contact time',
#  'complimentary dog food',
#  'alcohol magnum classic',
#  'selection makes',
#  '13 %), basmati rice',
#  'salt 10 snacks free',
#  'ron gillies wine',
#  'original soreen malt loaf',
#  'carrot ), chilli peppers',
#  '3 origin',
#  'com asda long grain rice',
#  'honeysuckle 630 ml fairy fairy clean',
#  'morning oats golden oaty 60g milk',
#  'fine milk chocolate egg since 1845',
#  'rich meat dishes',
#  'rare sensitising properties',
#  'battery tester',
#  'toast topper',
#  'punchy writing',
#  'carmine )] great meals start',
#  'visible improvement',
#  'red seedless grapes film',
#  'aleurites moluccanus seed extract',
#  'sad looking skin',
#  'restorative system',
#  'mono \xad',
#  'tastic flavour !, source',
#  'check local recycling arden',
#  'control microbial deterioration cuts',
#  'deliciously creamy caramel',
#  '12months +,',
#  'affineurs',
#  'crisp biscuit piece since launch since',
#  'nutritionally need',
#  'well rounded premium amber ale packed',
#  'distinct cereal character',
#  'almond 50 washes 1',
#  'natural flavouring perfect porridge',
#  'audio recorder found near',
#  'vividly colourful light blue',
#  'combining beer',
#  '1141',
#  'bht leave',
#  'black pepper ), tawny port',
#  'dettol antibacterial surface cleanser',
#  'good boy meaty treaty chicken fillet',
#  'ginger variants',
#  'tiger tomatoes',
#  'contains sabra sabra',
#  'also adhering',
#  'necklace 1 pack talking tables',
#  'starch anti',
#  'garlic 250g waitrose seasonally tender lamb',
#  'milk ), plum',
#  'loved blend',
#  'pampering wash',
#  'patons',
#  'starch alternative',
#  'oil †, glycerin',
#  '5 %), coconut blossom nectar',
#  '3kg asda pork',
#  '40 %) 4 snack packs',
#  'potassium sorbate e202 sub tropical fruits',
#  'average cereal bar †. lovely stuff',
#  'tasty snack pot available',
#  'carefully selected ex',
#  'thiamin ], full fat soft cheese',
#  'go british chicken',
#  'six different vegetables',
#  '18 %), rusk',
#  'operatives receive',
#  'seal 20 food',
#  '15g burt',
#  'propylene glycol alginate ), onion puree',
#  'highly digestible wholegrain brown rice',
#  'gentle caring formula',
#  'mrs ladybird',
#  'high adhesion',
#  'immense charme',
#  'daily hydrating moisturiser hydrates skin',
#  'others keep refrigerated',
#  '19 %)( maize flour',
#  'grow back',
#  'release trigger',
#  'small yet powerful',
#  'occasion solving',
#  'vit advance',
#  'comfort made',
#  'jacks chocolate rice cakes',
#  'authentic ingredient',
#  'face bar suitable',
#  'low calorie sugar alternative derives',
#  'duck paté',
#  'waitrose heritage collection white jasmine',
#  'better savour',
#  'young ale creates',
#  'etc ., removes odour causing bacteria',
#  'tested multi',
#  'moma oat original contains 1g',
#  'coconut chocolate bar 70g nuts',
#  'positively brimming',
#  'contains barone ricasoli',
#  '48 women **** clinical scoring',
#  'warm african sun',
#  'mcdougalls instant thickening granules 170g soya',
#  '60 days *.',
#  'jaffa crew',
#  'croutons 215g eggs',
#  'tresemme delivers professional quality',
#  'reduce impact',
#  'replicated anywhere else',
#  'care hand',
#  '40 teabag carton',
#  'mccain southern fries 750g wheat',
#  'water 400g widely recycled co',
#  'one medium carrot',
#  'deep clean shampoo',
#  'furniture pieces look like new',
#  'duracell recharge ultra batteries',
#  'nutrition cereals **',
#  'unique environment',
#  'inspired baubles 335g film',
#  'heineken lager beer 650ml barley',
#  'fringe mop refill',
#  'per sachet ): sodium alginate 225mg',
#  '35 %), refined sunflower oil',
#  '10μg vitamin',
#  'bees feeding',
#  'perspirant stick deodorant provides',
#  'base mixed material',
#  'liftaction',
#  'painful pressure',
#  'dean 75cl plumpton estate',
#  'lindor maxi ball',
#  'vintage cheddar bloomer unbranded',
#  'attracting makeup',
#  'amylase ), perfumes even removes baked',
#  '19 l fairy fairy clean',
#  'cream contains bio argan oil',
#  'sellotape zero plastic tape roll sellotape',
#  'rubberised grips',
#  'natural sweetening needs',
#  'fish ), mustard seeds',
#  'may contain cofresh monkey nuts britain',
#  'contains remove',
#  'additional ageing brings complexity',
#  'yunnan green',
#  'proper apple pie 550g milk',
#  'small wounds including cuts',
#  'fixes volume styles',
#  'tating note bright garnet',
#  'soothe kool',
#  'eu agriculture enjoy',
#  'grape must ), butter',
#  '91 %), cocoa solids 72',
#  'soaked sardinian menu',
#  'eye liner',
#  'bodywash allows',
#  'unflavoured collagen',
#  '229 kcal 973 kj per cup',
#  'wholegrain jumbo oat flakes',
#  'secondary renal hyperparathyroidism ., source',
#  'ballpoint writes',
#  'worlds †. made',
#  'wear additives',
#  'freshly toasted',
#  'ireland 2018 recommended',
#  'taste luxurious',
#  'based burger patties',
#  'delicious mexican filings',
#  'product provides bouncy looks',
#  'fertilisers protein helps',
#  'may contain porrelli mint ice cream',
#  'adult cats needs',
#  'rich wine form',
#  '18 %), lasagne pasta sheets',
#  'minimum easter treats',
#  'rich liquorice taste',
#  'migraine migraleve yellow',
#  '16 weeks feed',
#  '207ml box',
#  'milk chocolate orange 157g milk',
#  'days aqua',
#  '4 %), chestnut mushroom',
#  'page turner full',
#  'mangos per 100g',
#  'original tick tock',
#  'mollica baked',
#  'salt free peanut butter',
#  'powered ‡ medley',
#  'alcohol denat ., disodium deceth',
#  'richer drinking experience',
#  'ethylhexylglycerin false eyelashes',
#  'conditioner 450ml head',
#  'california sushi roll inside',
#  'sodium nitrate )], sugar',
#  'health matters 2 pregnancy tests carton',
#  'proclaimed',
#  'awards winner 2017',
#  'subtle shimmer',
#  'reliably powering everyday devices',
#  'soya )), flavouring ),, sugar',
#  'p88',
#  '480 drink perrier',
#  'lower absorbency',
#  'foaming shower gel',
#  'acrylates copolymer anti',
#  'holiday cheer',
#  'op still mandarin',
#  'contains humza chicken 43 %, onion',
#  '40 mins oven cook',
#  'midday indulgence',
#  'custom look',
#  'please refill',
#  'favourite objects',
#  'plant sterol intake',
#  'contains yeo valley organic',
#  'waitrose 12 days',
#  'help keep teeth clean',
#  'energizer cr2016 lithium batteries perform',
#  'free eco wipes',
#  'stronger teeth reduces plaque',
#  'erythritol 250g bag',
#  'citric acid ), calcium chloride',
#  'spinach pie milk',
#  'rapeseed oil ), cooked chicken',
#  'spicy curry sauce',
#  'dog kibbles helps clean',
#  '1 %) free',
#  'ginsters ham',
#  'sun blessed south america',
#  'little ones chicken curry',
#  'fine pure cane sugar',
#  'gmo free keep refrigerated',
#  'intense absorption',
#  'get pregnant faster',
#  'athlone sweets fruit jellies 170g nuts',
#  'cornflour ), smoked bacon',
#  'may contain black magic',
#  'wild lilac',
#  'fruitypot jelly tropical fruit 120g sleeve',
#  'tea breads',
#  'eye steak',
#  'quorn ®,',
#  'asda consumers',
#  'dual ended applicator',
#  'used oral',
#  'energizer ® accu recharge maxi charger',
#  '0 %, cardamom 0',
#  'multigrain special k',
#  'added shimmer',
#  '568ml co',
#  'modena 215ml sulphur dioxide',
#  'senior large breed dogs',
#  'crispy butter',
#  'box !,',
#  'agreement satisfaction',
#  'mouth chocolate enrobing',
#  '35 %*), cereals',
#  'sauces vibrant',
#  'tasty chunky banana',
#  'ex sherry casks',
#  'com www',
#  '30g ): yeast extract',
#  '20 %), flavouring',
#  'precisely merged',
#  'grease removal freshness booster',
#  'sugar ), dried whole milk',
#  '4 taste',
#  'pine nuts 100g',
#  'multi surface',
#  'op pistachio nut kernels 100g nuts',
#  'tangy citrus resulting',
#  'bees ® coconut foot cream',
#  'suitable part',
#  'delicious fusion',
#  'parfum intensive protection',
#  'versatile grated mature cheddar',
#  'worrying lump',
#  'recyclable carplan want',
#  'pak ® clausthaler water',
#  'almond pralines gift box 15 pieces',
#  'like texture 12 dinner dumplings',
#  'tropical lagering process',
#  'info .), long',
#  'boil 15 minutes',
#  'situation –',
#  'kill ...',
#  'highly effective formulation containing 25',
#  'family bakery nestled',
#  'sharpie markers',
#  'cocoa butter full',
#  'cap ), helps protect coloured hair',
#  'limonene refillable',
#  'turn screams',
#  'dairy crest limited',
#  'toy robots',
#  'stylish single grain scotch whisky rooted',
#  'prevent infections anti',
#  'spirulina ), produced',
#  '27 billion live cultures',
#  'nut safe promise',
#  'safewrap snap',
#  'rice krispies cereal 510g barley',
#  'plant pioneers 12 sage',
#  'vaginal',
#  'streaky gradual sun',
#  'roast onion extract',
#  'tesco crinkle cut gherkins 340g mustard',
#  'contains widely recycled asda tomatoes',
#  '5kg westland moss prevention',
#  'grower withholds water',
#  'cucumissativus',
#  'chamomile recutita',
#  'romantic rose combined',
#  'floors experience',
#  'protected geographical indication status',
#  '‘ like freshly picked apple',
#  'bacon cereals containing gluten',
#  'lovely pop',
#  'offshore pilsner 12 x 330ml barley',
#  'high temperatures create',
#  '83 %), coating',
#  'highly coveted industry awards since',
#  'smooth milky centre containing',
#  '97 calories per bar',
#  'contains quorn wheat flour',
#  'visibly reduced flakes',
#  'menoflavon ® botanical extract used',
#  'pronutra ™- advance',
#  'new zealand slant',
#  'contemporary coupe side plate',
#  'moving mountasin ® meatballs',
#  'kids logo',
#  'waitrose 1 potato',
#  'methylisothiazolinone hydrating hair conditioner',
#  'water ], ground',
#  'marsh samphire',
#  'crafted individual batches form',
#  'thai curry parcels milk',
#  'lenor fabric conditioner gold orchid 540ml',
#  'palm fat suitable',
#  'vileda ultramax 1',
#  'pineapple juice 432g please recycle steel',
#  'pectin british cream',
#  'lactococcus lacts subsp ., streptococcus thermophilus',
#  'soya lecithin ), glazing agents',
#  'best premium turkey breast 120g gluten',
#  'saccharomyces platinum ferment',
#  'avocado toast',
#  '5 litres pmp € 4',
#  'op fairtrade santa',
#  '6 christmas cupcakes 309g',
#  'category winner',
#  'seeds rather',
#  'sticky jasmine rice',
#  'ishka sparkling water 500ml ishka',
#  'renaming',
#  'draw hair like strokes',
#  '3d cleaning action',
#  'lengthy maturation make',
#  'ultra absorbent resistant fringes',
#  'potato starch crunchy',
#  'thiamin great taste award 2017',
#  'annatto norbixin ), glucose syrup',
#  'please contact po box 4044',
#  'milk notes soft',
#  'raccoon find',
#  'subtle delicate florals',
#  '7 %), chestnut',
#  '5 %, maize starch',
#  '8 red pepper',
#  '5l lamb',
#  'superb intensity',
#  'perfect white spirit',
#  'recycle morrisons supplied',
#  '11 %), salt made',
#  'contains higgidy spiced cauliflower',
#  'contains waitrose free range pork',
#  'punchy cracked pepper',
#  'natural flavourings ready',
#  'healthy cleaning everyday',
#  'proper green tea',
#  'pectin ), chicken stock powder',
#  'finished beef jerky craft jerky snacks',
#  'get omega',
#  'slow roasted beans',
#  'heating sugar',
#  'healthy looking every day',
#  'sugar free formula',
#  'highly absorbent cellulose',
#  'free toner',
#  'endeavors',
#  'get fruity bars get fruity',
#  'polyphosphates ), coconut oil',
#  'ballygowan still water 1',
#  'benefits dry skin',
#  'chicory tones',
#  'barr cola 2l bottle barr sweet',
#  'classics corned beef hash 400g milk',
#  'spirit vinegar ], soft cheese filling',
#  'dry electric razor braun',
#  'sodium nitrite ), wheat dextrose',
#  'creamier formula easier application biotin',
#  'natural shaped teat',
#  'burns night',
#  '5ml essie essie lapiz',
#  'harrogate black tea black',
#  'salmon herring chicken',
#  '020 carton',
#  'fun mini size',
#  'op tomato juice 1 litre co',
#  'sugar apple',
#  'finished look',
#  'pub snack',
#  'melts great !, suitable',
#  'contains alpro pretty peachy',
#  'check locally vale',
#  '1242510',
#  'contemporary tastes',
#  'whose dung',
#  'non plastic',
#  'long grain aromatic rice',
#  'contains lanson blend',
#  'use vo5 thickening hair paste',
#  'paprika extract ), sunflower oil 100',
#  'reveals vibrant colours',
#  'herbs basmati rice 250g gluten',
#  'ci 15850 vaseline prime',
#  'lack body',
#  'lurpak ®',
#  'sugar free sweets',
#  'table water black pepper 125g milk',
#  'shipping',
#  'prawn pouches',
#  'knorr professional classic cream',
#  'nishiki river',
#  'paprika grown delicious',
#  'decadent taste full',
#  'frugo suuper fruits mango flavour',
#  'results guaranteed !, advanced peptide technology',
#  'foot solution',
#  'chemical fertilisers',
#  'sunflower lecithin source',
#  'potato dishes feathery fragrant fronds',
#  'salted peas',
#  'skin ., skin tolerance dermatologically approved',
#  'hot condiment',
#  'safflower ), milk fat',
#  'may contain purely purely plantain chips',
#  'vanilla frozen yoghurt',
#  'nimble laundry lover baby detergent 1l',
#  'clarify',
#  '18 %), pork sausages',
#  'chunky chocolate chips',
#  'consortium',
#  'e296 ), concentrated lemon juice',
#  '1 non',
#  'perspirant cream stick gives',
#  'asda coleslaw 600g eggs',
#  'flame grilled chicken breast slices',
#  'lift mousse 300ml',
#  'light tonic',
#  'sodium alginate casings new',
#  'gives full coverage without',
#  'tier british cheese wedding cake unbranded',
#  'master distiller krister asplund',
#  '57 %), high oleic sunflower oil',
#  'delicate vodka',
#  '5mins',
#  'hochland maasdamer cheese slices 135g milk',
#  'bold flavour certain',
#  'citronellol tough',
#  'soft breathable',
#  'cold !, vegan friendly keep refrigerated',
#  'milk ), flavouring keep refrigerated',
#  'sunflower ], sour cream',
#  'sulphur dioxide alcohol free wine',
#  'erase like',
#  'rio mare msc tuna',
#  'float ...',
#  'juul berry',
#  'folded sandwich',
#  'macphie béchamel',
#  'honestly made',
#  '10 local authorities',
#  'often wild',
#  '30 dipolyhydroxystearate tocopherol',
#  'dried oranges',
#  'rose 250ml belvoir farm',
#  '2 %), colours',
#  'asda marrowfat peas 300g clean',
#  'hobs excluding induction',
#  'lice repellent',
#  '27 kcal per 10g serving',
#  'clonakilty blackpudding co',
#  '415kj 99kcal per 1',
#  'sodium citrate british allergy foundation',
#  '40 %), cooked chicken breast',
#  'sheba soup wet cat food',
#  'special diet',
#  'mowbray 4 snack pork pies eggs',
#  'gelling agent pectin }, cinnamon',
#  'spontex everyday household gloves',
#  '10 features',
#  'isopropyl myristate cetearyl alcohol',
#  'op gravy biscuit bones treats',
#  '6 %), flaked almonds',
#  'spa experience without',
#  'soya )), flavouring ), salted butter',
#  'filter coffee machine',
#  '250 ml organics',
#  'absorbent ideal',
#  'moisturising properties fragranced',
#  'naturally inhibits bacteria growth',
#  'recyclable de kuyper crème de cassis',
#  'selection 3 grapefruit asda slice',
#  '29 %), chillies',
#  'mighty meat feast pizza barley',
#  'e412 ), mono',
#  'average snack bar',
#  'one jar',
#  'hard floor cleaner',
#  'integrated non scratch scrubbing tip',
#  '9 %), eggs',
#  'shaved black truffle',
#  'achieves bitter',
#  'asda 4 assorted cream cake selection',
#  'potassium sorbate british milk',
#  'uncompromising precision',
#  'fragrance c179224',
#  'delicate white florals meet creamy musk',
#  'unique thirst pocket technology locks',
#  'garnier coconut milk body lotion',
#  'classic feline flick',
#  'meat selection',
#  'louth using',
#  'peri sauce medium 500g gluten',
#  'white baguettes',
#  'butter lovers',
#  'spiced fruits',
#  'convenient fresh flavour solution',
#  '4 %), raisin',
#  'carlyn paton',
#  'alcohol denat ., stearyl alcohol',
#  'triphosphates ), cracked black pepper',
#  'neills pork meat',
#  'sultanas suitable',
#  'partners edam 310g milk',
#  'twice cooked crunchy taco shells',
#  'loves dinosaurs',
#  'whilst lower carbonation delivers',
#  'intense blackness without sticking lashes together',
#  'sulphites ), lemon juice',
#  'recyclable kelkin corn flour',
#  'oetker chocolate chip pud',
#  'mash happy',
#  'white clothes anti',
#  'sodium citrate fragrance',
#  'gentle maturation',
#  'black pepper 80g 1 portion 5',
#  'shred proof silky floss',
#  'ammonium bicarbonate )), wheat flour',
#  'picturesque countryside',
#  'try adding crispy bacon',
#  'shelf friendly packaging',
#  'part kit',
#  'iconic ibérico pigs',
#  'cyfluthrin kiwi ® shoe polish',
#  'tracks two key fertility hormones',
#  'yet recycled tesco beetroot',
#  'vegetarian rennet organic',
#  'kitchen cleaner ** –',
#  'real good food',
#  'first ever rechargeable battery system',
#  ...]

# %% [markdown]
# Compare existing Phrases

# %%
df_combined = df_new.merge(df_old, on='Phrase', how='left')
df_combined
# Out:
#                                 Phrase  Score_x  Length_x    Perc_x  Count_x  \
# 0                             contains     7928         1  1.076919   8395.0
# 1                          may contain     5579         2  0.757837   2845.0
# 2                             suitable     5158         1  0.700650   6210.0
# 3                                 salt     4711         1  0.639930   5642.0
# 4                                sugar     4652         1  0.631916   6089.0
# ...                                ...      ...       ...       ...      ...
# 159696               1 %), dried herbs        1         4  0.000136      1.0
# 159697              1 %), skimmed cows        1         4  0.000136      1.0
# 159698  parsley ), natural flavourings        1         4  0.000136      1.0
# 159699       tasty honey mustard sauce        1         4  0.000136      1.0
# 159700                              "[        1         1  0.000136      1.0
#
#         Score_y  Length_y    Perc_y  Count_y
# 0       19980.0       1.0  1.086187  19295.0
# 1       13021.0       2.0  0.707870   6827.0
# 2       11652.0       1.0  0.633446  14411.0
# 3       11870.0       1.0  0.645297  13396.0
# 4       11586.0       1.0  0.629858  14156.0
# ...         ...       ...       ...      ...
# 159696      1.0       4.0  0.000054      1.0
# 159697      NaN       NaN       NaN      NaN
# 159698      2.0       4.0  0.000109      0.0
# 159699      NaN       NaN       NaN      NaN
# 159700      1.0       1.0  0.000054      1.0
#
# [159701 rows x 9 columns]

# %%
df_combined = df_combined.rename(columns={'Perc_x': 'Score_Frequency_x', 
                                            'Perc_y': 'Score_Frequency_y'},
                                            )

# %%
def get_perc_increase(row):
    return ((row['Score_Frequency_x']-row['Score_Frequency_y'])/row['Score_Frequency_y'])*100

def get_score_increase(row):
    return ((row['Score_x']-row['Score_y'])/row['Score_y'])*100

def get_count_frequency_increase_x(row,sum):
    return (row['Count_x']/sum*100)

def get_count_frequency_increase_y(row,sum):
    return (row['Count_y']/sum*100)

def get_count_increase(row):
    if row['Count_Frequency_y'] !=0:
        return ((row['Count_Frequency_x']-row['Count_Frequency_y'])/row['Count_Frequency_y'])*100
    else:
        return 0

# %%
sum = df_combined['Count_x'].sum()
df_combined['Count_Frequency_x'] = df_combined.apply (lambda row: get_count_frequency_increase_x(row,sum), axis=1)
df_combined['Count_Frequency_y'] = df_combined.apply (lambda row: get_count_frequency_increase_y(row,sum), axis=1)
df_combined['Count_Frequency_Increase'] = df_combined.apply (lambda row: get_count_increase(row), axis=1)

# %%
df_combined['Score_Frequency_increase'] = df_combined.apply (lambda row: get_perc_increase(row), axis=1)

# %%
df_combined
# Out:
#                                 Phrase  Score_x  Length_x  Score_Frequency_x  \
# 0                             contains     7928         1           1.076919
# 1                          may contain     5579         2           0.757837
# 2                             suitable     5158         1           0.700650
# 3                                 salt     4711         1           0.639930
# 4                                sugar     4652         1           0.631916
# ...                                ...      ...       ...                ...
# 159696               1 %), dried herbs        1         4           0.000136
# 159697              1 %), skimmed cows        1         4           0.000136
# 159698  parsley ), natural flavourings        1         4           0.000136
# 159699       tasty honey mustard sauce        1         4           0.000136
# 159700                              "[        1         1           0.000136
#
#         Count_x  Score_y  Length_y  Score_Frequency_y  Count_y  \
# 0        8395.0  19980.0       1.0           1.086187  19295.0
# 1        2845.0  13021.0       2.0           0.707870   6827.0
# 2        6210.0  11652.0       1.0           0.633446  14411.0
# 3        5642.0  11870.0       1.0           0.645297  13396.0
# 4        6089.0  11586.0       1.0           0.629858  14156.0
# ...         ...      ...       ...                ...      ...
# 159696      1.0      1.0       4.0           0.000054      1.0
# 159697      1.0      NaN       NaN                NaN      NaN
# 159698      1.0      2.0       4.0           0.000109      0.0
# 159699      1.0      NaN       NaN                NaN      NaN
# 159700      1.0      1.0       1.0           0.000054      1.0
#
#         Count_Frequency_x  Count_Frequency_y  Count_Frequency_Increase  \
# 0                0.267326           0.614421                -56.491319
# 1                0.090595           0.217396                -58.327230
# 2                0.197748           0.458897                -56.907918
# 3                0.179661           0.426576                -57.882950
# 4                0.193895           0.450777                -56.986437
# ...                   ...                ...                       ...
# 159696           0.000032           0.000032                  0.000000
# 159697           0.000032                NaN                       NaN
# 159698           0.000032           0.000000                  0.000000
# 159699           0.000032                NaN                       NaN
# 159700           0.000032           0.000032                  0.000000
#
#         Score_Frequency_increase
# 0                      -0.853191
# 1                       7.058857
# 2                      10.609249
# 3                      -0.831678
# 4                       0.326755
# ...                          ...
# 159696                149.867966
# 159697                       NaN
# 159698                 24.933983
# 159699                       NaN
# 159700                149.867966
#
# [159701 rows x 13 columns]

# %%
df_combined['Score_increase'] = df_combined.apply (lambda row: get_score_increase(row), axis=1)

# %%
df_combined
# Out:
#                                 Phrase  Score_x  Length_x  Score_Frequency_x  \
# 0                             contains     7928         1           1.076919
# 1                          may contain     5579         2           0.757837
# 2                             suitable     5158         1           0.700650
# 3                                 salt     4711         1           0.639930
# 4                                sugar     4652         1           0.631916
# ...                                ...      ...       ...                ...
# 159696               1 %), dried herbs        1         4           0.000136
# 159697              1 %), skimmed cows        1         4           0.000136
# 159698  parsley ), natural flavourings        1         4           0.000136
# 159699       tasty honey mustard sauce        1         4           0.000136
# 159700                              "[        1         1           0.000136
#
#         Count_x  Score_y  Length_y  Score_Frequency_y  Count_y  \
# 0        8395.0  19980.0       1.0           1.086187  19295.0
# 1        2845.0  13021.0       2.0           0.707870   6827.0
# 2        6210.0  11652.0       1.0           0.633446  14411.0
# 3        5642.0  11870.0       1.0           0.645297  13396.0
# 4        6089.0  11586.0       1.0           0.629858  14156.0
# ...         ...      ...       ...                ...      ...
# 159696      1.0      1.0       4.0           0.000054      1.0
# 159697      1.0      NaN       NaN                NaN      NaN
# 159698      1.0      2.0       4.0           0.000109      0.0
# 159699      1.0      NaN       NaN                NaN      NaN
# 159700      1.0      1.0       1.0           0.000054      1.0
#
#         Count_Frequency_x  Count_Frequency_y  Count_Frequency_Increase  \
# 0                0.267326           0.614421                -56.491319
# 1                0.090595           0.217396                -58.327230
# 2                0.197748           0.458897                -56.907918
# 3                0.179661           0.426576                -57.882950
# 4                0.193895           0.450777                -56.986437
# ...                   ...                ...                       ...
# 159696           0.000032           0.000032                  0.000000
# 159697           0.000032                NaN                       NaN
# 159698           0.000032           0.000000                  0.000000
# 159699           0.000032                NaN                       NaN
# 159700           0.000032           0.000032                  0.000000
#
#         Score_Frequency_increase  Score_increase
# 0                      -0.853191      -60.320320
# 1                       7.058857      -57.153828
# 2                      10.609249      -55.732921
# 3                      -0.831678      -60.311710
# 4                       0.326755      -59.848093
# ...                          ...             ...
# 159696                149.867966        0.000000
# 159697                       NaN             NaN
# 159698                 24.933983      -50.000000
# 159699                       NaN             NaN
# 159700                149.867966        0.000000
#
# [159701 rows x 14 columns]

# %%
df_combined.to_csv(r'Extracted Phrases\Rake NLTK\Latest Phrase Comparison.csv')
